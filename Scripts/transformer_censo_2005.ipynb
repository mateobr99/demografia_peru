# %%
import pandas as pd
import numpy as np
import openpyxl
import os
import xlrd
from pathlib import Path
from openpyxl import load_workbook
import re
ARCHIVO_ORIGEN = r"D:\Mateo\ICSI\Proyecto\Data\Raw\Poblacion\Data\Inputs\Censo\censo_pob_sexo_edades_quin_2005.xlsx"
AÑO_CENSO = 2005
df = pd.read_excel(ARCHIVO_ORIGEN)

def procesar_censo_corregido(df):
    """
    Procesa el formato corregido del censo
    """
    datos_procesados = []
    area_actual = {"ubigeo": "", "departamento": ""}
    
    # Reiniciar índices y columnas
    df = df.reset_index(drop=True)
    df.columns = [str(i) for i in range(len(df.columns))]
    
    i = 0
    while i < len(df):
        fila = df.iloc[i]
        
        # 1. Buscar área geográfica (fila con "AREA" en columna 0 y nombre en columna 1)
        if pd.notna(fila['0']) and 'AREA' in str(fila['0']):
            # Extraer ubigeo de la columna 0
            area_texto = str(fila['0'])
            ubigeo_match = re.search(r'(\d{6})', area_texto)
            area_actual['ubigeo'] = ubigeo_match.group(1) if ubigeo_match else ""
            
            # Extraer departamento de la columna 1
            if pd.notna(fila['1']):
                area_actual['departamento'] = str(fila['1']).strip()
            else:
                area_actual['departamento'] = ""
            
            print(f"Encontrada área: Ubigeo={area_actual['ubigeo']}, Departamento={area_actual['departamento']}")
            i += 1
            continue
        
        # 2. Buscar inicio de tabla de datos (fila con "Edad" en columna 0 y "Sexo" en columna 1)
        if (pd.notna(fila['0']) and 'Edad' in str(fila['0']) and 
            pd.notna(fila['1']) and 'Sexo' in str(fila['1'])):
            
            print(f"Encontrado encabezado de tabla en fila {i}")
            
            # La siguiente fila (i+1) tiene los encabezados de sexo
            if i + 1 < len(df):
                fila_encabezados = df.iloc[i + 1]
                
                # Verificar que tiene Hombre, Mujer, Total en las columnas correctas
                if (pd.notna(fila_encabezados['1']) and 'Hombre' in str(fila_encabezados['1']) and
                    pd.notna(fila_encabezados['2']) and 'Mujer' in str(fila_encabezados['2']) and
                    pd.notna(fila_encabezados['3']) and 'Total' in str(fila_encabezados['3'])):
                    
                    print("Encabezados de sexo confirmados")
                    
                    # Procesar filas de datos desde i+2
                    j = i + 2
                    while j < len(df):
                        fila_datos = df.iloc[j]
                        
                        # Si encuentra nueva área, terminar
                        if pd.notna(fila_datos['0']) and 'AREA' in str(fila_datos['0']):
                            break
                            
                        # Si es una fila vacía o de totales, saltar
                        if pd.isna(fila_datos['0']) or str(fila_datos['0']).strip() == '':
                            j += 1
                            continue
                            
                        # Si es fila de datos (contiene "Grupo de" o rangos de edad)
                        if (pd.notna(fila_datos['0']) and 
                            ('Grupo de' in str(fila_datos['0']) or 
                             '-' in str(fila_datos['0']) or 
                             'a' in str(fila_datos['0']))):
                            
                            grupo_edad = str(fila_datos['0']).strip()
                            
                            # Procesar las tres columnas de datos (Hombre, Mujer, Total)
                            for col_idx, sexo in [(1, 'Hombre'), (2, 'Mujer'), (3, 'Total')]:
                                if str(col_idx) in fila_datos.index:
                                    valor = fila_datos[str(col_idx)]
                                    if (pd.notna(valor) and 
                                        str(valor).strip() not in ['', '-', 'nan', 'None']):
                                        try:
                                            # Convertir a número (manejar posibles comas)
                                            valor_str = str(valor).replace(',', '').strip()
                                            valor_num = float(valor_str)
                                            
                                            datos_procesados.append({
                                                'Ubigeo': area_actual['ubigeo'],
                                                'Departamento': area_actual['departamento'],
                                                'grupo_edad': grupo_edad,
                                                'sexo': sexo,
                                                'valor': valor_num
                                            })
                                            
                                        except ValueError:
                                            print(f"Error convirtiendo valor: {valor}")
                                            continue
                        elif 'Total' in str(fila_datos['0']):
                            # Fila de total general, podemos saltarla o procesarla
                            pass
                            
                        j += 1
                    
                    # Avanzar al final del bloque procesado
                    i = j - 1
        
        i += 1
    
    # Crear DataFrame final
    df_final = pd.DataFrame(datos_procesados)
    
    if not df_final.empty:
        # Limpiar grupo_edad
        df_final['grupo_edad'] = df_final['grupo_edad'].str.replace('Grupo de', '').str.strip()
        
        # Convertir valor a numérico
        df_final['valor'] = pd.to_numeric(df_final['valor'], errors='coerce')
        df_final = df_final.dropna(subset=['valor'])
    
    return df_final

# Procesar el DataFrame
df_final = procesar_censo_corregido(df)

print("=== RESULTADO FINAL ===")
print(f"Total de registros: {len(df_final)}")
print(f"\nPrimeros 10 registros:")
print(df_final.head(10))
print(f"\nEstadísticas:")
print(f"Ubigeos únicos: {df_final['Ubigeo'].nunique()}")
print(f"Departamentos: {df_final['Departamento'].unique()}")
print(f"Distribución por sexo:\n{df_final['sexo'].value_counts()}")

def formatear_grupo_edad(grupo_edad):
    if pd.isna(grupo_edad):
        return grupo_edad
    grupo = str(grupo_edad).strip()

    if grupo.startswith('De') and 'años' in grupo:
        return grupo
    
    if '-' in grupo:
        partes = grupo.split('-')
        if len(partes) == 2:
            try:
                inicio = partes[0].strip()
                fin = partes[1].strip()
                return f"De {inicio} a {fin} años"
            except:
                return grupo
    return grupo

#Aplicar la función

df_final['grupo_edad'] = df_final['grupo_edad'].apply(formatear_grupo_edad) 

df_final['Anio'] = 2005 
df_final['Ubigeo'] = df_final['Ubigeo'].astype(str)

import os
ruta_destino = r"D:\Mateo\ICSI\Proyecto\Data\Raw\Poblacion\Data\Processing"
nombre_archivo = "pob_censo_edades_sexo_2005.csv"
ruta_completa = os.path.join(ruta_destino, nombre_archivo)
df_final.to_csv(ruta_completa, index=False, encoding='latin1')
# Out:
# Encontrada área: Ubigeo=010101, Departamento=CHACHAPOYAS
# Encontrado encabezado de tabla en fila 3
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010102, Departamento=ASUNCION
# Encontrado encabezado de tabla en fila 29
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010103, Departamento=BALSAS
# Encontrado encabezado de tabla en fila 54
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010104, Departamento=CHETO
# Encontrado encabezado de tabla en fila 80
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010105, Departamento=CHILIQUIN
# Encontrado encabezado de tabla en fila 105
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010106, Departamento=CHUQUIBAMBA
# Encontrado encabezado de tabla en fila 130
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010107, Departamento=GRANADA
# Encontrado encabezado de tabla en fila 156
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010108, Departamento=HUANCAS
# Encontrado encabezado de tabla en fila 181
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010109, Departamento=LA JALCA
# Encontrado encabezado de tabla en fila 206
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010110, Departamento=LEIMEBAMBA
# Encontrado encabezado de tabla en fila 232
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010111, Departamento=LEVANTO
# Encontrado encabezado de tabla en fila 258
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010112, Departamento=MAGDALENA
# Encontrado encabezado de tabla en fila 283
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010113, Departamento=MARISCAL CASTILLA
# Encontrado encabezado de tabla en fila 309
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010114, Departamento=MOLINOPAMPA
# Encontrado encabezado de tabla en fila 334
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010115, Departamento=MONTEVIDEO
# Encontrado encabezado de tabla en fila 360
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010116, Departamento=OLLEROS
# Encontrado encabezado de tabla en fila 385
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010117, Departamento=QUINJALCA
# Encontrado encabezado de tabla en fila 409
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010118, Departamento=SAN FRANCISCO DE DAGUAS
# Encontrado encabezado de tabla en fila 435
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010119, Departamento=SAN ISIDRO DE MAINO
# Encontrado encabezado de tabla en fila 460
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010120, Departamento=SOLOCO
# Encontrado encabezado de tabla en fila 484
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010121, Departamento=SONCHE
# Encontrado encabezado de tabla en fila 510
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010201, Departamento=LA PECA
# Encontrado encabezado de tabla en fila 535
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010202, Departamento=ARAMANGO
# Encontrado encabezado de tabla en fila 561
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010203, Departamento=COPALLIN
# Encontrado encabezado de tabla en fila 587
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010204, Departamento=EL PARCO
# Encontrado encabezado de tabla en fila 613
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010205, Departamento=IMAZA
# Encontrado encabezado de tabla en fila 638
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010301, Departamento=JUMBILLA
# Encontrado encabezado de tabla en fila 664
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010302, Departamento=CHISQUILLA
# Encontrado encabezado de tabla en fila 690
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010303, Departamento=CHURUJA
# Encontrado encabezado de tabla en fila 715
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010304, Departamento=COROSHA
# Encontrado encabezado de tabla en fila 740
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010305, Departamento=CUISPES
# Encontrado encabezado de tabla en fila 764
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010306, Departamento=FLORIDA
# Encontrado encabezado de tabla en fila 788
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010307, Departamento=JAZAN
# Encontrado encabezado de tabla en fila 813
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010308, Departamento=RECTA
# Encontrado encabezado de tabla en fila 839
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010309, Departamento=SAN CARLOS
# Encontrado encabezado de tabla en fila 863
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010310, Departamento=SHIPASBAMBA
# Encontrado encabezado de tabla en fila 888
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010311, Departamento=VALERA
# Encontrado encabezado de tabla en fila 913
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010312, Departamento=YAMBRASBAMBA
# Encontrado encabezado de tabla en fila 939
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010401, Departamento=NIEVA
# Encontrado encabezado de tabla en fila 965
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010402, Departamento=EL CENEPA
# Encontrado encabezado de tabla en fila 991
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010403, Departamento=RIO SANTIAGO
# Encontrado encabezado de tabla en fila 1016
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010501, Departamento=LAMUD
# Encontrado encabezado de tabla en fila 1042
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010502, Departamento=CAMPORREDONDO
# Encontrado encabezado de tabla en fila 1068
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010503, Departamento=COCABAMBA
# Encontrado encabezado de tabla en fila 1094
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010504, Departamento=COLCAMAR
# Encontrado encabezado de tabla en fila 1120
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010505, Departamento=CONILA
# Encontrado encabezado de tabla en fila 1146
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010506, Departamento=INGUILPATA
# Encontrado encabezado de tabla en fila 1172
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010507, Departamento=LONGUITA
# Encontrado encabezado de tabla en fila 1198
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010508, Departamento=LONYA CHICO
# Encontrado encabezado de tabla en fila 1224
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010509, Departamento=LUYA
# Encontrado encabezado de tabla en fila 1249
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010510, Departamento=LUYA VIEJO
# Encontrado encabezado de tabla en fila 1275
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010511, Departamento=MARIA
# Encontrado encabezado de tabla en fila 1300
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010512, Departamento=OCALLI
# Encontrado encabezado de tabla en fila 1325
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010513, Departamento=OCUMAL
# Encontrado encabezado de tabla en fila 1351
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010514, Departamento=PISUQUIA
# Encontrado encabezado de tabla en fila 1376
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010515, Departamento=PROVIDENCIA
# Encontrado encabezado de tabla en fila 1402
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010516, Departamento=SAN CRISTOBAL
# Encontrado encabezado de tabla en fila 1428
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010517, Departamento=SAN FRANCISCO DEL YESO
# Encontrado encabezado de tabla en fila 1454
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010518, Departamento=SAN JERONIMO
# Encontrado encabezado de tabla en fila 1479
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010519, Departamento=SAN JUAN DE LOPECANCHA
# Encontrado encabezado de tabla en fila 1505
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010520, Departamento=SANTA CATALINA
# Encontrado encabezado de tabla en fila 1530
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010521, Departamento=SANTO TOMAS
# Encontrado encabezado de tabla en fila 1555
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010522, Departamento=TINGO
# Encontrado encabezado de tabla en fila 1581
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010523, Departamento=TRITA
# Encontrado encabezado de tabla en fila 1607
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010601, Departamento=SAN NICOLAS
# Encontrado encabezado de tabla en fila 1632
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010602, Departamento=CHIRIMOTO
# Encontrado encabezado de tabla en fila 1658
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010603, Departamento=COCHAMAL
# Encontrado encabezado de tabla en fila 1683
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010604, Departamento=HUAMBO
# Encontrado encabezado de tabla en fila 1707
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010605, Departamento=LIMABAMBA
# Encontrado encabezado de tabla en fila 1733
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010606, Departamento=LONGAR
# Encontrado encabezado de tabla en fila 1759
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010607, Departamento=MARISCAL BENAVIDES
# Encontrado encabezado de tabla en fila 1785
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010608, Departamento=MILPUC
# Encontrado encabezado de tabla en fila 1811
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010609, Departamento=OMIA
# Encontrado encabezado de tabla en fila 1835
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010610, Departamento=SANTA ROSA
# Encontrado encabezado de tabla en fila 1860
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010611, Departamento=TOTORA
# Encontrado encabezado de tabla en fila 1886
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010612, Departamento=VISTA ALEGRE
# Encontrado encabezado de tabla en fila 1910
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010701, Departamento=BAGUA GRANDE
# Encontrado encabezado de tabla en fila 1934
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010702, Departamento=CAJARURO
# Encontrado encabezado de tabla en fila 1960
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010703, Departamento=CUMBA
# Encontrado encabezado de tabla en fila 1986
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010704, Departamento=EL MILAGRO
# Encontrado encabezado de tabla en fila 2012
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010705, Departamento=JAMALCA
# Encontrado encabezado de tabla en fila 2038
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010706, Departamento=LONYA GRANDE
# Encontrado encabezado de tabla en fila 2064
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=010707, Departamento=YAMON
# Encontrado encabezado de tabla en fila 2090
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020101, Departamento=HUARAZ
# Encontrado encabezado de tabla en fila 2116
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020102, Departamento=COCHABAMBA
# Encontrado encabezado de tabla en fila 2142
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020103, Departamento=COLCABAMBA
# Encontrado encabezado de tabla en fila 2168
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020104, Departamento=HUANCHAY
# Encontrado encabezado de tabla en fila 2193
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020105, Departamento=INDEPENDENCIA
# Encontrado encabezado de tabla en fila 2219
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020106, Departamento=JANGAS
# Encontrado encabezado de tabla en fila 2245
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020107, Departamento=LA LIBERTAD
# Encontrado encabezado de tabla en fila 2271
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020108, Departamento=OLLEROS
# Encontrado encabezado de tabla en fila 2296
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020109, Departamento=PAMPAS
# Encontrado encabezado de tabla en fila 2322
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020110, Departamento=PARIACOTO
# Encontrado encabezado de tabla en fila 2348
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020111, Departamento=PIRA
# Encontrado encabezado de tabla en fila 2374
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020112, Departamento=TARICA
# Encontrado encabezado de tabla en fila 2400
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020201, Departamento=AIJA
# Encontrado encabezado de tabla en fila 2426
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020202, Departamento=CORIS
# Encontrado encabezado de tabla en fila 2452
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020203, Departamento=HUACLLAN
# Encontrado encabezado de tabla en fila 2478
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020204, Departamento=LA MERCED
# Encontrado encabezado de tabla en fila 2503
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020205, Departamento=SUCCHA
# Encontrado encabezado de tabla en fila 2529
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020301, Departamento=LLAMELLIN
# Encontrado encabezado de tabla en fila 2555
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020302, Departamento=ACZO
# Encontrado encabezado de tabla en fila 2581
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020303, Departamento=CHACCHO
# Encontrado encabezado de tabla en fila 2607
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020304, Departamento=CHINGAS
# Encontrado encabezado de tabla en fila 2633
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020305, Departamento=MIRGAS
# Encontrado encabezado de tabla en fila 2659
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020306, Departamento=SAN JUAN DE RONTOY
# Encontrado encabezado de tabla en fila 2685
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020401, Departamento=CHACAS
# Encontrado encabezado de tabla en fila 2711
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020402, Departamento=ACOCHACA
# Encontrado encabezado de tabla en fila 2737
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020501, Departamento=CHIQUIAN
# Encontrado encabezado de tabla en fila 2763
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020502, Departamento=ABELARDO PARDO LEZAMETA
# Encontrado encabezado de tabla en fila 2789
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020503, Departamento=ANTONIO RAYMONDI
# Encontrado encabezado de tabla en fila 2814
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020504, Departamento=AQUIA
# Encontrado encabezado de tabla en fila 2840
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020505, Departamento=CAJACAY
# Encontrado encabezado de tabla en fila 2866
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020506, Departamento=CANIS
# Encontrado encabezado de tabla en fila 2892
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020507, Departamento=COLQUIOC
# Encontrado encabezado de tabla en fila 2917
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020508, Departamento=HUALLANCA
# Encontrado encabezado de tabla en fila 2943
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020509, Departamento=HUASTA
# Encontrado encabezado de tabla en fila 2969
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020510, Departamento=HUAYLLACAYAN
# Encontrado encabezado de tabla en fila 2995
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020511, Departamento=LA PRIMAVERA
# Encontrado encabezado de tabla en fila 3020
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020512, Departamento=MANGAS
# Encontrado encabezado de tabla en fila 3044
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020513, Departamento=PACLLON
# Encontrado encabezado de tabla en fila 3070
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020514, Departamento=SAN MIGUEL DE CORPANQUI
# Encontrado encabezado de tabla en fila 3095
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020515, Departamento=TICLLOS
# Encontrado encabezado de tabla en fila 3120
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020601, Departamento=CARHUAZ
# Encontrado encabezado de tabla en fila 3145
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020602, Departamento=ACOPAMPA
# Encontrado encabezado de tabla en fila 3171
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020603, Departamento=AMASHCA
# Encontrado encabezado de tabla en fila 3197
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020604, Departamento=ANTA
# Encontrado encabezado de tabla en fila 3223
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020605, Departamento=ATAQUERO
# Encontrado encabezado de tabla en fila 3249
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020606, Departamento=MARCARA
# Encontrado encabezado de tabla en fila 3274
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020607, Departamento=PARIAHUANCA
# Encontrado encabezado de tabla en fila 3300
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020608, Departamento=SAN MIGUEL DE ACO
# Encontrado encabezado de tabla en fila 3326
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020609, Departamento=SHILLA
# Encontrado encabezado de tabla en fila 3352
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020610, Departamento=TINCO
# Encontrado encabezado de tabla en fila 3377
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020611, Departamento=YUNGAR
# Encontrado encabezado de tabla en fila 3403
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020701, Departamento=SAN LUIS
# Encontrado encabezado de tabla en fila 3429
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020702, Departamento=SAN NICOLAS
# Encontrado encabezado de tabla en fila 3455
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020703, Departamento=YAUYA
# Encontrado encabezado de tabla en fila 3481
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020801, Departamento=CASMA
# Encontrado encabezado de tabla en fila 3507
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020802, Departamento=BUENA VISTA ALTA
# Encontrado encabezado de tabla en fila 3533
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020803, Departamento=COMANDANTE NOEL
# Encontrado encabezado de tabla en fila 3559
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020804, Departamento=YAUTAN
# Encontrado encabezado de tabla en fila 3585
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020901, Departamento=CORONGO
# Encontrado encabezado de tabla en fila 3611
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020902, Departamento=ACO
# Encontrado encabezado de tabla en fila 3637
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020903, Departamento=BAMBAS
# Encontrado encabezado de tabla en fila 3663
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020904, Departamento=CUSCA
# Encontrado encabezado de tabla en fila 3688
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020905, Departamento=LA PAMPA
# Encontrado encabezado de tabla en fila 3714
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020906, Departamento=YANAC
# Encontrado encabezado de tabla en fila 3740
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=020907, Departamento=YUPAN
# Encontrado encabezado de tabla en fila 3766
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021001, Departamento=HUARI
# Encontrado encabezado de tabla en fila 3790
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021002, Departamento=ANRA
# Encontrado encabezado de tabla en fila 3816
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021003, Departamento=CAJAY
# Encontrado encabezado de tabla en fila 3842
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021004, Departamento=CHAVIN DE HUANTAR
# Encontrado encabezado de tabla en fila 3868
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021005, Departamento=HUACACHI
# Encontrado encabezado de tabla en fila 3894
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021006, Departamento=HUACCHIS
# Encontrado encabezado de tabla en fila 3920
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021007, Departamento=HUACHIS
# Encontrado encabezado de tabla en fila 3946
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021008, Departamento=HUANTAR
# Encontrado encabezado de tabla en fila 3972
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021009, Departamento=MASIN
# Encontrado encabezado de tabla en fila 3998
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021010, Departamento=PAUCAS
# Encontrado encabezado de tabla en fila 4024
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021011, Departamento=PONTO
# Encontrado encabezado de tabla en fila 4050
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021012, Departamento=RAHUAPAMPA
# Encontrado encabezado de tabla en fila 4076
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021013, Departamento=RAPAYAN
# Encontrado encabezado de tabla en fila 4102
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021014, Departamento=SAN MARCOS
# Encontrado encabezado de tabla en fila 4128
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021015, Departamento=SAN PEDRO DE CHANA
# Encontrado encabezado de tabla en fila 4154
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021016, Departamento=UCO
# Encontrado encabezado de tabla en fila 4180
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021101, Departamento=HUARMEY
# Encontrado encabezado de tabla en fila 4206
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021102, Departamento=COCHAPETI
# Encontrado encabezado de tabla en fila 4232
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021103, Departamento=CULEBRAS
# Encontrado encabezado de tabla en fila 4257
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021104, Departamento=HUAYAN
# Encontrado encabezado de tabla en fila 4283
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021105, Departamento=MALVAS
# Encontrado encabezado de tabla en fila 4308
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021201, Departamento=CARAZ
# Encontrado encabezado de tabla en fila 4334
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021202, Departamento=HUALLANCA
# Encontrado encabezado de tabla en fila 4360
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021203, Departamento=HUATA
# Encontrado encabezado de tabla en fila 4385
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021204, Departamento=HUAYLAS
# Encontrado encabezado de tabla en fila 4411
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021205, Departamento=MATO
# Encontrado encabezado de tabla en fila 4437
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021206, Departamento=PAMPAROMAS
# Encontrado encabezado de tabla en fila 4463
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021207, Departamento=PUEBLO LIBRE
# Encontrado encabezado de tabla en fila 4489
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021208, Departamento=SANTA CRUZ
# Encontrado encabezado de tabla en fila 4515
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021209, Departamento=SANTO TORIBIO
# Encontrado encabezado de tabla en fila 4541
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021210, Departamento=YURACMARCA
# Encontrado encabezado de tabla en fila 4567
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021301, Departamento=PISCOBAMBA
# Encontrado encabezado de tabla en fila 4593
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021302, Departamento=CASCA
# Encontrado encabezado de tabla en fila 4619
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021303, Departamento=ELEAZAR GUZMAN BARRON
# Encontrado encabezado de tabla en fila 4645
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021304, Departamento=FIDEL OLIVAS ESCUDERO
# Encontrado encabezado de tabla en fila 4670
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021305, Departamento=LLAMA
# Encontrado encabezado de tabla en fila 4695
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021306, Departamento=LLUMPA
# Encontrado encabezado de tabla en fila 4721
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021307, Departamento=LUCMA
# Encontrado encabezado de tabla en fila 4746
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021308, Departamento=MUSGA
# Encontrado encabezado de tabla en fila 4772
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021401, Departamento=OCROS
# Encontrado encabezado de tabla en fila 4798
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021402, Departamento=ACAS
# Encontrado encabezado de tabla en fila 4824
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021403, Departamento=CAJAMARQUILLA
# Encontrado encabezado de tabla en fila 4850
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021404, Departamento=CARHUAPAMPA
# Encontrado encabezado de tabla en fila 4874
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021405, Departamento=COCHAS
# Encontrado encabezado de tabla en fila 4898
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021406, Departamento=CONGAS
# Encontrado encabezado de tabla en fila 4922
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021407, Departamento=LLIPA
# Encontrado encabezado de tabla en fila 4948
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021408, Departamento=SAN CRISTOBAL DE RAJAN
# Encontrado encabezado de tabla en fila 4972
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021409, Departamento=SAN PEDRO
# Encontrado encabezado de tabla en fila 4998
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021410, Departamento=SANTIAGO DE CHILCAS
# Encontrado encabezado de tabla en fila 5024
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021501, Departamento=CABANA
# Encontrado encabezado de tabla en fila 5050
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021502, Departamento=BOLOGNESI
# Encontrado encabezado de tabla en fila 5076
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021503, Departamento=CONCHUCOS
# Encontrado encabezado de tabla en fila 5102
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021504, Departamento=HUACASCHUQUE
# Encontrado encabezado de tabla en fila 5128
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021505, Departamento=HUANDOVAL
# Encontrado encabezado de tabla en fila 5154
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021506, Departamento=LACABAMBA
# Encontrado encabezado de tabla en fila 5179
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021507, Departamento=LLAPO
# Encontrado encabezado de tabla en fila 5205
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021508, Departamento=PALLASCA
# Encontrado encabezado de tabla en fila 5230
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021509, Departamento=PAMPAS
# Encontrado encabezado de tabla en fila 5256
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021510, Departamento=SANTA ROSA
# Encontrado encabezado de tabla en fila 5282
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021511, Departamento=TAUCA
# Encontrado encabezado de tabla en fila 5308
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021601, Departamento=POMABAMBA
# Encontrado encabezado de tabla en fila 5334
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021602, Departamento=HUAYLLAN
# Encontrado encabezado de tabla en fila 5360
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021603, Departamento=PAROBAMBA
# Encontrado encabezado de tabla en fila 5385
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021604, Departamento=QUINUABAMBA
# Encontrado encabezado de tabla en fila 5411
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021701, Departamento=RECUAY
# Encontrado encabezado de tabla en fila 5437
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021702, Departamento=CATAC
# Encontrado encabezado de tabla en fila 5463
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021703, Departamento=COTAPARACO
# Encontrado encabezado de tabla en fila 5489
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021704, Departamento=HUAYLLAPAMPA
# Encontrado encabezado de tabla en fila 5515
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021705, Departamento=LLACLLIN
# Encontrado encabezado de tabla en fila 5540
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021706, Departamento=MARCA
# Encontrado encabezado de tabla en fila 5566
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021707, Departamento=PAMPAS CHICO
# Encontrado encabezado de tabla en fila 5592
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021708, Departamento=PARARIN
# Encontrado encabezado de tabla en fila 5617
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021709, Departamento=TAPACOCHA
# Encontrado encabezado de tabla en fila 5643
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021710, Departamento=TICAPAMPA
# Encontrado encabezado de tabla en fila 5669
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021801, Departamento=CHIMBOTE
# Encontrado encabezado de tabla en fila 5695
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021802, Departamento=CACERES DEL PERU
# Encontrado encabezado de tabla en fila 5721
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021803, Departamento=COISHCO
# Encontrado encabezado de tabla en fila 5747
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021804, Departamento=MACATE
# Encontrado encabezado de tabla en fila 5773
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021805, Departamento=MORO
# Encontrado encabezado de tabla en fila 5799
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021806, Departamento=NEPEÑA
# Encontrado encabezado de tabla en fila 5825
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021807, Departamento=SAMANCO
# Encontrado encabezado de tabla en fila 5851
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021808, Departamento=SANTA
# Encontrado encabezado de tabla en fila 5877
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021809, Departamento=NUEVO CHIMBOTE
# Encontrado encabezado de tabla en fila 5903
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021901, Departamento=SIHUAS
# Encontrado encabezado de tabla en fila 5929
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021902, Departamento=ACOBAMBA
# Encontrado encabezado de tabla en fila 5955
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021903, Departamento=ALFONSO UGARTE
# Encontrado encabezado de tabla en fila 5981
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021904, Departamento=CASHAPAMPA
# Encontrado encabezado de tabla en fila 6006
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021905, Departamento=CHINGALPO
# Encontrado encabezado de tabla en fila 6032
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021906, Departamento=HUAYLLABAMBA
# Encontrado encabezado de tabla en fila 6057
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021907, Departamento=QUICHES
# Encontrado encabezado de tabla en fila 6083
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021908, Departamento=RAGASH
# Encontrado encabezado de tabla en fila 6109
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021909, Departamento=SAN JUAN
# Encontrado encabezado de tabla en fila 6135
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=021910, Departamento=SICSIBAMBA
# Encontrado encabezado de tabla en fila 6161
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=022001, Departamento=YUNGAY
# Encontrado encabezado de tabla en fila 6187
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=022002, Departamento=CASCAPARA
# Encontrado encabezado de tabla en fila 6213
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=022003, Departamento=MANCOS
# Encontrado encabezado de tabla en fila 6238
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=022004, Departamento=MATACOTO
# Encontrado encabezado de tabla en fila 6264
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=022005, Departamento=QUILLO
# Encontrado encabezado de tabla en fila 6290
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=022006, Departamento=RANRAHIRCA
# Encontrado encabezado de tabla en fila 6316
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=022007, Departamento=SHUPLUY
# Encontrado encabezado de tabla en fila 6342
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=022008, Departamento=YANAMA
# Encontrado encabezado de tabla en fila 6368
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030101, Departamento=ABANCAY
# Encontrado encabezado de tabla en fila 6394
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030102, Departamento=CHACOCHE
# Encontrado encabezado de tabla en fila 6420
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030103, Departamento=CIRCA
# Encontrado encabezado de tabla en fila 6446
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030104, Departamento=CURAHUASI
# Encontrado encabezado de tabla en fila 6472
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030105, Departamento=HUANIPACA
# Encontrado encabezado de tabla en fila 6498
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030106, Departamento=LAMBRAMA
# Encontrado encabezado de tabla en fila 6524
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030107, Departamento=PICHIRHUA
# Encontrado encabezado de tabla en fila 6550
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030108, Departamento=SAN PEDRO DE CACHORA
# Encontrado encabezado de tabla en fila 6576
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030109, Departamento=TAMBURCO
# Encontrado encabezado de tabla en fila 6602
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030201, Departamento=ANDAHUAYLAS
# Encontrado encabezado de tabla en fila 6628
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030202, Departamento=ANDARAPA
# Encontrado encabezado de tabla en fila 6654
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030203, Departamento=CHIARA
# Encontrado encabezado de tabla en fila 6680
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030204, Departamento=HUANCARAMA
# Encontrado encabezado de tabla en fila 6706
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030205, Departamento=HUANCARAY
# Encontrado encabezado de tabla en fila 6732
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030206, Departamento=HUAYANA
# Encontrado encabezado de tabla en fila 6758
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030207, Departamento=KISHUARA
# Encontrado encabezado de tabla en fila 6784
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030208, Departamento=PACOBAMBA
# Encontrado encabezado de tabla en fila 6810
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030209, Departamento=PACUCHA
# Encontrado encabezado de tabla en fila 6836
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030210, Departamento=PAMPACHIRI
# Encontrado encabezado de tabla en fila 6862
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030211, Departamento=POMACOCHA
# Encontrado encabezado de tabla en fila 6888
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030212, Departamento=SAN ANTONIO DE CACHI
# Encontrado encabezado de tabla en fila 6914
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030213, Departamento=SAN JERONIMO
# Encontrado encabezado de tabla en fila 6940
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030214, Departamento=SAN MIGUEL DE CHACCRAMPA
# Encontrado encabezado de tabla en fila 6966
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030215, Departamento=SANTA MARIA DE CHICMO
# Encontrado encabezado de tabla en fila 6992
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030216, Departamento=TALAVERA
# Encontrado encabezado de tabla en fila 7018
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030217, Departamento=TUMAY HUARACA
# Encontrado encabezado de tabla en fila 7044
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030218, Departamento=TURPO
# Encontrado encabezado de tabla en fila 7069
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030219, Departamento=KAQUIABAMBA
# Encontrado encabezado de tabla en fila 7095
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030301, Departamento=ANTABAMBA
# Encontrado encabezado de tabla en fila 7121
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030302, Departamento=EL ORO
# Encontrado encabezado de tabla en fila 7147
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030303, Departamento=HUAQUIRCA
# Encontrado encabezado de tabla en fila 7173
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030304, Departamento=JUAN ESPINOZA MEDRANO
# Encontrado encabezado de tabla en fila 7199
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030305, Departamento=OROPESA
# Encontrado encabezado de tabla en fila 7225
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030306, Departamento=PACHACONAS
# Encontrado encabezado de tabla en fila 7251
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030307, Departamento=SABAINO
# Encontrado encabezado de tabla en fila 7276
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030401, Departamento=CHALHUANCA
# Encontrado encabezado de tabla en fila 7302
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030402, Departamento=CAPAYA
# Encontrado encabezado de tabla en fila 7328
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030403, Departamento=CARAYBAMBA
# Encontrado encabezado de tabla en fila 7354
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030404, Departamento=CHAPIMARCA
# Encontrado encabezado de tabla en fila 7379
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030405, Departamento=COLCABAMBA
# Encontrado encabezado de tabla en fila 7405
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030406, Departamento=COTARUSE
# Encontrado encabezado de tabla en fila 7430
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030407, Departamento=HUAYLLO
# Encontrado encabezado de tabla en fila 7455
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030408, Departamento=JUSTO APU SAHUARAURA
# Encontrado encabezado de tabla en fila 7481
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030409, Departamento=LUCRE
# Encontrado encabezado de tabla en fila 7506
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030410, Departamento=POCOHUANCA
# Encontrado encabezado de tabla en fila 7532
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030411, Departamento=SAN JUAN DE CHACÑA
# Encontrado encabezado de tabla en fila 7558
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030412, Departamento=SAÑAYCA
# Encontrado encabezado de tabla en fila 7584
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030413, Departamento=SORAYA
# Encontrado encabezado de tabla en fila 7610
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030414, Departamento=TAPAIRIHUA
# Encontrado encabezado de tabla en fila 7636
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030415, Departamento=TINTAY
# Encontrado encabezado de tabla en fila 7662
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030416, Departamento=TORAYA
# Encontrado encabezado de tabla en fila 7688
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030417, Departamento=YANACA
# Encontrado encabezado de tabla en fila 7714
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030501, Departamento=TAMBOBAMBA
# Encontrado encabezado de tabla en fila 7740
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030502, Departamento=COTABAMBAS
# Encontrado encabezado de tabla en fila 7766
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030503, Departamento=COYLLURQUI
# Encontrado encabezado de tabla en fila 7791
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030504, Departamento=HAQUIRA
# Encontrado encabezado de tabla en fila 7817
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030505, Departamento=MARA
# Encontrado encabezado de tabla en fila 7843
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030506, Departamento=CHALLHUAHUACHO
# Encontrado encabezado de tabla en fila 7869
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030601, Departamento=CHINCHEROS
# Encontrado encabezado de tabla en fila 7895
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030602, Departamento=ANCO_HUALLO
# Encontrado encabezado de tabla en fila 7921
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030603, Departamento=COCHARCAS
# Encontrado encabezado de tabla en fila 7947
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030604, Departamento=HUACCANA
# Encontrado encabezado de tabla en fila 7973
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030605, Departamento=OCOBAMBA
# Encontrado encabezado de tabla en fila 7999
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030606, Departamento=ONGOY
# Encontrado encabezado de tabla en fila 8025
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030607, Departamento=URANMARCA
# Encontrado encabezado de tabla en fila 8051
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030608, Departamento=RANRACANCHA
# Encontrado encabezado de tabla en fila 8077
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030701, Departamento=CHUQUIBAMBILLA
# Encontrado encabezado de tabla en fila 8103
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030702, Departamento=CURPAHUASI
# Encontrado encabezado de tabla en fila 8129
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030703, Departamento=GAMARRA
# Encontrado encabezado de tabla en fila 8155
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030704, Departamento=HUAYLLATI
# Encontrado encabezado de tabla en fila 8181
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030705, Departamento=MAMARA
# Encontrado encabezado de tabla en fila 8207
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030706, Departamento=MICAELA BASTIDAS
# Encontrado encabezado de tabla en fila 8233
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030707, Departamento=PATAYPAMPA
# Encontrado encabezado de tabla en fila 8259
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030708, Departamento=PROGRESO
# Encontrado encabezado de tabla en fila 8284
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030709, Departamento=SAN ANTONIO
# Encontrado encabezado de tabla en fila 8310
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030710, Departamento=SANTA ROSA
# Encontrado encabezado de tabla en fila 8336
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030711, Departamento=TURPAY
# Encontrado encabezado de tabla en fila 8362
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030712, Departamento=VILCABAMBA
# Encontrado encabezado de tabla en fila 8387
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030713, Departamento=VIRUNDO
# Encontrado encabezado de tabla en fila 8413
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=030714, Departamento=CURASCO
# Encontrado encabezado de tabla en fila 8439
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040101, Departamento=AREQUIPA
# Encontrado encabezado de tabla en fila 8465
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040102, Departamento=ALTO SELVA ALEGRE
# Encontrado encabezado de tabla en fila 8491
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040103, Departamento=CAYMA
# Encontrado encabezado de tabla en fila 8517
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040104, Departamento=CERRO COLORADO
# Encontrado encabezado de tabla en fila 8543
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040105, Departamento=CHARACATO
# Encontrado encabezado de tabla en fila 8569
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040106, Departamento=CHIGUATA
# Encontrado encabezado de tabla en fila 8595
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040107, Departamento=JACOBO HUNTER
# Encontrado encabezado de tabla en fila 8621
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040108, Departamento=LA JOYA
# Encontrado encabezado de tabla en fila 8647
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040109, Departamento=MARIANO MELGAR
# Encontrado encabezado de tabla en fila 8673
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040110, Departamento=MIRAFLORES
# Encontrado encabezado de tabla en fila 8699
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040111, Departamento=MOLLEBAYA
# Encontrado encabezado de tabla en fila 8725
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040112, Departamento=PAUCARPATA
# Encontrado encabezado de tabla en fila 8751
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040113, Departamento=POCSI
# Encontrado encabezado de tabla en fila 8777
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040114, Departamento=POLOBAYA
# Encontrado encabezado de tabla en fila 8802
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040115, Departamento=QUEQUEÑA
# Encontrado encabezado de tabla en fila 8828
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040116, Departamento=SABANDIA
# Encontrado encabezado de tabla en fila 8854
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040117, Departamento=SACHACA
# Encontrado encabezado de tabla en fila 8880
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040118, Departamento=SAN JUAN DE SIGUAS
# Encontrado encabezado de tabla en fila 8906
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040119, Departamento=SAN JUAN DE TARUCANI
# Encontrado encabezado de tabla en fila 8932
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040120, Departamento=SANTA ISABEL DE SIGUAS
# Encontrado encabezado de tabla en fila 8958
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040121, Departamento=SANTA RITA DE SIGUAS
# Encontrado encabezado de tabla en fila 8983
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040122, Departamento=SOCABAYA
# Encontrado encabezado de tabla en fila 9009
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040123, Departamento=TIABAYA
# Encontrado encabezado de tabla en fila 9035
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040124, Departamento=UCHUMAYO
# Encontrado encabezado de tabla en fila 9061
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040125, Departamento=VITOR
# Encontrado encabezado de tabla en fila 9087
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040126, Departamento=YANAHUARA
# Encontrado encabezado de tabla en fila 9113
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040127, Departamento=YARABAMBA
# Encontrado encabezado de tabla en fila 9139
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040128, Departamento=YURA
# Encontrado encabezado de tabla en fila 9165
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040129, Departamento=JOSE LUIS BUSTAMANTE Y RIVERO
# Encontrado encabezado de tabla en fila 9191
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040201, Departamento=CAMANA
# Encontrado encabezado de tabla en fila 9217
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040202, Departamento=JOSE MARIA QUIMPER
# Encontrado encabezado de tabla en fila 9243
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040203, Departamento=MARIANO NICOLAS VALCARCEL
# Encontrado encabezado de tabla en fila 9268
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040204, Departamento=MARISCAL CACERES
# Encontrado encabezado de tabla en fila 9293
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040205, Departamento=NICOLAS DE PIEROLA
# Encontrado encabezado de tabla en fila 9319
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040206, Departamento=OCOÑA
# Encontrado encabezado de tabla en fila 9345
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040207, Departamento=QUILCA
# Encontrado encabezado de tabla en fila 9371
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=040208, Departamento=SAMUEL PASTOR
# Encontrado encabezado de tabla en fila 9396
# Encabezados de sexo confirmados
# ...
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220305, Departamento=SHATOJA
# Encontrado encabezado de tabla en fila 44300
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220401, Departamento=SAPOSOA
# Encontrado encabezado de tabla en fila 44325
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220402, Departamento=ALTO SAPOSOA
# Encontrado encabezado de tabla en fila 44351
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220403, Departamento=EL ESLABON
# Encontrado encabezado de tabla en fila 44376
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220404, Departamento=PISCOYACU
# Encontrado encabezado de tabla en fila 44402
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220405, Departamento=SACANCHE
# Encontrado encabezado de tabla en fila 44428
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220406, Departamento=TINGO DE SAPOSOA
# Encontrado encabezado de tabla en fila 44454
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220501, Departamento=LAMAS
# Encontrado encabezado de tabla en fila 44480
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220502, Departamento=ALONSO DE ALVARADO
# Encontrado encabezado de tabla en fila 44506
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220503, Departamento=BARRANQUITA
# Encontrado encabezado de tabla en fila 44532
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220504, Departamento=CAYNARACHI
# Encontrado encabezado de tabla en fila 44558
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220505, Departamento=CUÑUMBUQUI
# Encontrado encabezado de tabla en fila 44583
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220506, Departamento=PINTO RECODO
# Encontrado encabezado de tabla en fila 44608
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220507, Departamento=RUMISAPA
# Encontrado encabezado de tabla en fila 44634
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220508, Departamento=SAN ROQUE DE CUMBAZA
# Encontrado encabezado de tabla en fila 44660
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220509, Departamento=SHANAO
# Encontrado encabezado de tabla en fila 44685
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220510, Departamento=TABALOSOS
# Encontrado encabezado de tabla en fila 44711
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220511, Departamento=ZAPATERO
# Encontrado encabezado de tabla en fila 44737
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220601, Departamento=JUANJUI
# Encontrado encabezado de tabla en fila 44763
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220602, Departamento=CAMPANILLA
# Encontrado encabezado de tabla en fila 44789
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220603, Departamento=HUICUNGO
# Encontrado encabezado de tabla en fila 44814
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220604, Departamento=PACHIZA
# Encontrado encabezado de tabla en fila 44840
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220605, Departamento=PAJARILLO
# Encontrado encabezado de tabla en fila 44866
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220701, Departamento=PICOTA
# Encontrado encabezado de tabla en fila 44891
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220702, Departamento=BUENOS AIRES
# Encontrado encabezado de tabla en fila 44917
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220703, Departamento=CASPISAPA
# Encontrado encabezado de tabla en fila 44943
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220704, Departamento=PILLUANA
# Encontrado encabezado de tabla en fila 44967
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220705, Departamento=PUCACACA
# Encontrado encabezado de tabla en fila 44992
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220706, Departamento=SAN CRISTOBAL
# Encontrado encabezado de tabla en fila 45018
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220707, Departamento=SAN HILARION
# Encontrado encabezado de tabla en fila 45044
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220708, Departamento=SHAMBOYACU
# Encontrado encabezado de tabla en fila 45070
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220709, Departamento=TINGO DE PONASA
# Encontrado encabezado de tabla en fila 45096
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220710, Departamento=TRES UNIDOS
# Encontrado encabezado de tabla en fila 45121
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220801, Departamento=RIOJA
# Encontrado encabezado de tabla en fila 45147
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220802, Departamento=AWAJUN
# Encontrado encabezado de tabla en fila 45173
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220803, Departamento=ELIAS SOPLIN VARGAS
# Encontrado encabezado de tabla en fila 45199
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220804, Departamento=NUEVA CAJAMARCA
# Encontrado encabezado de tabla en fila 45225
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220805, Departamento=PARDO MIGUEL
# Encontrado encabezado de tabla en fila 45251
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220806, Departamento=POSIC
# Encontrado encabezado de tabla en fila 45277
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220807, Departamento=SAN FERNANDO
# Encontrado encabezado de tabla en fila 45301
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220808, Departamento=YORONGOS
# Encontrado encabezado de tabla en fila 45326
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220809, Departamento=YURACYACU
# Encontrado encabezado de tabla en fila 45352
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220901, Departamento=TARAPOTO
# Encontrado encabezado de tabla en fila 45378
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220902, Departamento=ALBERTO LEVEAU
# Encontrado encabezado de tabla en fila 45404
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220903, Departamento=CACATACHI
# Encontrado encabezado de tabla en fila 45429
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220904, Departamento=CHAZUTA
# Encontrado encabezado de tabla en fila 45455
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220905, Departamento=CHIPURANA
# Encontrado encabezado de tabla en fila 45481
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220906, Departamento=EL PORVENIR
# Encontrado encabezado de tabla en fila 45507
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220907, Departamento=HUIMBAYOC
# Encontrado encabezado de tabla en fila 45532
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220908, Departamento=JUAN GUERRA
# Encontrado encabezado de tabla en fila 45558
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220909, Departamento=LA BANDA DE SHILCAYO
# Encontrado encabezado de tabla en fila 45583
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220910, Departamento=MORALES
# Encontrado encabezado de tabla en fila 45609
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220911, Departamento=PAPAPLAYA
# Encontrado encabezado de tabla en fila 45635
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220912, Departamento=SAN ANTONIO
# Encontrado encabezado de tabla en fila 45660
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220913, Departamento=SAUCE
# Encontrado encabezado de tabla en fila 45686
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=220914, Departamento=SHAPAJA
# Encontrado encabezado de tabla en fila 45712
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=221001, Departamento=TOCACHE
# Encontrado encabezado de tabla en fila 45738
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=221002, Departamento=NUEVO PROGRESO
# Encontrado encabezado de tabla en fila 45764
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=221003, Departamento=POLVORA
# Encontrado encabezado de tabla en fila 45790
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=221004, Departamento=SHUNTE
# Encontrado encabezado de tabla en fila 45816
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=221005, Departamento=UCHIZA
# Encontrado encabezado de tabla en fila 45842
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230101, Departamento=TACNA
# Encontrado encabezado de tabla en fila 45868
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230102, Departamento=ALTO DE LA ALIANZA
# Encontrado encabezado de tabla en fila 45894
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230103, Departamento=CALANA
# Encontrado encabezado de tabla en fila 45920
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230104, Departamento=CIUDAD NUEVA
# Encontrado encabezado de tabla en fila 45946
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230105, Departamento=INCLAN
# Encontrado encabezado de tabla en fila 45972
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230106, Departamento=PACHIA
# Encontrado encabezado de tabla en fila 45998
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230107, Departamento=PALCA
# Encontrado encabezado de tabla en fila 46024
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230108, Departamento=POCOLLAY
# Encontrado encabezado de tabla en fila 46050
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230109, Departamento=SAMA
# Encontrado encabezado de tabla en fila 46076
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230110, Departamento=CORONEL GREGORIO ALBARRACIN LANCHIP
# Encontrado encabezado de tabla en fila 46101
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230201, Departamento=CANDARAVE
# Encontrado encabezado de tabla en fila 46127
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230202, Departamento=CAIRANI
# Encontrado encabezado de tabla en fila 46153
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230203, Departamento=CAMILACA
# Encontrado encabezado de tabla en fila 46179
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230204, Departamento=CURIBAYA
# Encontrado encabezado de tabla en fila 46205
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230205, Departamento=HUANUARA
# Encontrado encabezado de tabla en fila 46230
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230206, Departamento=QUILAHUANI
# Encontrado encabezado de tabla en fila 46256
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230301, Departamento=LOCUMBA
# Encontrado encabezado de tabla en fila 46282
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230302, Departamento=ILABAYA
# Encontrado encabezado de tabla en fila 46308
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230303, Departamento=ITE
# Encontrado encabezado de tabla en fila 46334
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230401, Departamento=TARATA
# Encontrado encabezado de tabla en fila 46360
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230402, Departamento=HEROES ALBARRACIN
# Encontrado encabezado de tabla en fila 46386
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230403, Departamento=ESTIQUE
# Encontrado encabezado de tabla en fila 46412
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230404, Departamento=ESTIQUE-PAMPA
# Encontrado encabezado de tabla en fila 46437
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230405, Departamento=SITAJARA
# Encontrado encabezado de tabla en fila 46462
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230406, Departamento=SUSAPAYA
# Encontrado encabezado de tabla en fila 46488
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230407, Departamento=TARUCACHI
# Encontrado encabezado de tabla en fila 46514
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=230408, Departamento=TICACO
# Encontrado encabezado de tabla en fila 46540
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=240101, Departamento=TUMBES
# Encontrado encabezado de tabla en fila 46566
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=240102, Departamento=CORRALES
# Encontrado encabezado de tabla en fila 46592
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=240103, Departamento=LA CRUZ
# Encontrado encabezado de tabla en fila 46618
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=240104, Departamento=PAMPAS DE HOSPITAL
# Encontrado encabezado de tabla en fila 46644
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=240105, Departamento=SAN JACINTO
# Encontrado encabezado de tabla en fila 46670
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=240106, Departamento=SAN JUAN DE LA VIRGEN
# Encontrado encabezado de tabla en fila 46696
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=240201, Departamento=ZORRITOS
# Encontrado encabezado de tabla en fila 46722
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=240202, Departamento=CASITAS
# Encontrado encabezado de tabla en fila 46748
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=240301, Departamento=ZARUMILLA
# Encontrado encabezado de tabla en fila 46774
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=240302, Departamento=AGUAS VERDES
# Encontrado encabezado de tabla en fila 46800
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=240303, Departamento=MATAPALO
# Encontrado encabezado de tabla en fila 46826
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=240304, Departamento=PAPAYAL
# Encontrado encabezado de tabla en fila 46851
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250101, Departamento=CALLERIA
# Encontrado encabezado de tabla en fila 46877
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250102, Departamento=CAMPOVERDE
# Encontrado encabezado de tabla en fila 46903
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250103, Departamento=IPARIA
# Encontrado encabezado de tabla en fila 46929
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250104, Departamento=MASISEA
# Encontrado encabezado de tabla en fila 46954
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250105, Departamento=YARINACOCHA
# Encontrado encabezado de tabla en fila 46980
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250106, Departamento=NUEVA REQUENA
# Encontrado encabezado de tabla en fila 47006
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250201, Departamento=RAYMONDI
# Encontrado encabezado de tabla en fila 47031
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250202, Departamento=SEPAHUA
# Encontrado encabezado de tabla en fila 47057
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250203, Departamento=TAHUANIA
# Encontrado encabezado de tabla en fila 47082
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250204, Departamento=YURUA
# Encontrado encabezado de tabla en fila 47108
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250301, Departamento=PADRE ABAD
# Encontrado encabezado de tabla en fila 47130
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250302, Departamento=IRAZOLA
# Encontrado encabezado de tabla en fila 47156
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250303, Departamento=CURIMANA
# Encontrado encabezado de tabla en fila 47182
# Encabezados de sexo confirmados
# Encontrada área: Ubigeo=250401, Departamento=PURUS
# Encontrado encabezado de tabla en fila 47207
# Encabezados de sexo confirmados
# === RESULTADO FINAL ===
# Total de registros: 113413
#
# Primeros 10 registros:
#    Ubigeo Departamento grupo_edad    sexo   valor
# 0  010101  CHACHAPOYAS        0-4  Hombre   993.0
# 1  010101  CHACHAPOYAS        0-4   Mujer   963.0
# 2  010101  CHACHAPOYAS        0-4   Total  1956.0
# 3  010101  CHACHAPOYAS        5-9  Hombre  1070.0
# 4  010101  CHACHAPOYAS        5-9   Mujer  1112.0
# 5  010101  CHACHAPOYAS        5-9   Total  2182.0
# 6  010101  CHACHAPOYAS      10-14  Hombre  1208.0
# 7  010101  CHACHAPOYAS      10-14   Mujer  1192.0
# 8  010101  CHACHAPOYAS      10-14   Total  2400.0
# 9  010101  CHACHAPOYAS      15-19  Hombre  1196.0
#
# Estadísticas:
# Ubigeos únicos: 1830
# Departamentos: ['CHACHAPOYAS' 'ASUNCION' 'BALSAS' ... 'IRAZOLA' 'CURIMANA' 'PURUS']
# Distribución por sexo:
# sexo
# Total     38077
# Mujer     37777
# Hombre    37559
# Name: count, dtype: int64
