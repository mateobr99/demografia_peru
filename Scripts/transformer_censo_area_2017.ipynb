# %%
import pandas as pd
import re

def dividir_ubicacion(ubicacion_str):
    """
    Divide la cadena de ubicación en departamento, provincia y distrito
    Ejemplo: "Amazonas, Chachapoyas, distrito: Chachapoyas" →
    {"departamento": "Amazonas", "provincia": "Chachapoyas", "distrito": "Chachapoyas"}
    """
    if pd.isna(ubicacion_str) or not isinstance(ubicacion_str, str):
        return {"departamento": "", "provincia": "", "distrito": ""}
    
    try:
        # Dividir por comas
        partes = [parte.strip() for parte in ubicacion_str.split(',')]
        
        departamento = partes[0] if len(partes) > 0 else ""
        provincia = partes[1] if len(partes) > 1 else ""
        
        # Extraer distrito (puede ser "distrito: Nombre" o solo el nombre)
        distrito = ""
        if len(partes) > 2:
            distrito_str = partes[2]
            if 'distrito:' in distrito_str.lower():
                distrito_match = re.search(r'distrito:\s*(.+)', distrito_str, re.IGNORECASE)
                distrito = distrito_match.group(1).strip() if distrito_match else distrito_str
            else:
                distrito = distrito_str
        
        return {
            "departamento": departamento,
            "provincia": provincia,
            "distrito": distrito
        }
    except:
        return {"departamento": "", "provincia": "", "distrito": ""}

def procesar_censo_completo(df, año_censo):
    """
    Procesa el censo y divide la ubicación en departamento, provincia y distrito
    """
    datos = []
    ubigeo_actual = ""
    ubicacion_actual = ""
    
    for i in range(len(df)):
        fila = df.iloc[i].tolist()
        
        # Buscar línea con AREA # (columna B - índice 1)
        if len(fila) > 1 and pd.notna(fila[1]) and 'AREA #' in str(fila[1]):
            # Extraer ubigeo
            match = re.search(r'AREA #\s*(\d{6})', str(fila[1]))
            if match:
                ubigeo_actual = match.group(1)
            
            # Extraer ubicación completa (columna C - índice 2)
            if len(fila) > 2 and pd.notna(fila[2]):
                ubicacion_actual = str(fila[2]).strip()
                
                # Dividir la ubicación
                ubicacion_dividida = dividir_ubicacion(ubicacion_actual)
                print(f"📌 {ubigeo_actual} - {ubicacion_dividida}")
            continue
        
        # Buscar datos de población (Urbano censal, Rural censal, Total)
        if (len(fila) > 1 and pd.notna(fila[1]) and 
            any(x in str(fila[1]) for x in ['Urbano censal', 'Rural censal', 'Total'])):
            
            try:
                tipo_area = str(fila[1]).strip()
                # Población en columna C (índice 2)
                if len(fila) > 2 and pd.notna(fila[2]):
                    # Limpiar número
                    num_str = str(fila[2]).replace(' ', '').replace(',', '')
                    poblacion = int(float(num_str))
                    
                    # Dividir la ubicación actual
                    ubicacion_dividida = dividir_ubicacion(ubicacion_actual)
                    
                    datos.append({
                        'ubigeo': ubigeo_actual,
                        'departamento': ubicacion_dividida['departamento'],
                        'provincia': ubicacion_dividida['provincia'],
                        'distrito': ubicacion_dividida['distrito'],
                        'tipo_area': tipo_area,
                        'poblacion': poblacion,
                        'anio': año_censo
                    })
                    print(f"   ➡️ {tipo_area}: {poblacion}")
            except Exception as e:
                print(f"Error procesando fila {i}: {e}")
                continue
    
    return pd.DataFrame(datos)

# Función alternativa para manejar diferentes formatos de ubicación
def dividir_ubicacion_avanzada(ubicacion_str):
    """
    Versión más robusta para dividir ubicación
    """
    if pd.isna(ubicacion_str) or not isinstance(ubicacion_str, str):
        return {"departamento": "", "provincia": "", "distrito": "", "ubicacion_original": ubicacion_str}
    
    try:
        # Patrones comunes
        patrones = [
            r'(.*?),\s*(.*?),\s*distrito:\s*(.+)',  # "Depto, Prov, distrito: Dist"
            r'(.*?),\s*(.*?),\s*(.+)',              # "Depto, Prov, Dist"
            r'(.*?),\s*(.+)',                       # "Depto, Dist" 
            r'(.*?)'                                # Solo Depto
        ]
        
        for patron in patrones:
            match = re.match(patron, ubicacion_str, re.IGNORECASE)
            if match:
                grupos = match.groups()
                departamento = grupos[0].strip()
                provincia = grupos[1].strip() if len(grupos) > 1 else ""
                distrito = grupos[2].strip() if len(grupos) > 2 else grupos[1].strip() if len(grupos) > 1 else ""
                
                # Limpiar "distrito:" si está presente
                if 'distrito:' in distrito.lower():
                    distrito = re.sub(r'distrito:\s*', '', distrito, flags=re.IGNORECASE).strip()
                
                return {
                    "departamento": departamento,
                    "provincia": provincia,
                    "distrito": distrito
                }
        
        # Si no coincide con ningún patrón, devolver todo como departamento
        return {
            "departamento": ubicacion_str,
            "provincia": "",
            "distrito": ""
        }
        
    except:
        return {"departamento": "", "provincia": "", "distrito": ""}

# EJECUCIÓN COMPLETA
print("🚀 INICIANDO PROCESAMIENTO COMPLETO")
ruta = r"D:\Mateo\ICSI\Proyecto\Data\Raw\Poblacion\Data\Inputs\Censo\censo_pob_area_2017.xlsx"
df = pd.read_excel(ruta, header=None)

# Procesar con división de ubicación
resultado = procesar_censo_completo(df, 2017)

if not resultado.empty:
    print(f"\n✅ PROCESAMIENTO COMPLETO EXITOSO!")
    print(f"📊 Total de registros: {len(resultado)}")
    
    # Mostrar estadísticas
    print(f"\n📈 ESTADÍSTICAS:")
    print(f"Departamentos únicos: {resultado['departamento'].nunique()}")
    print(f"Provincias únicas: {resultado['provincia'].nunique()}")
    print(f"Distritos únicos: {resultado['distrito'].nunique()}")
    print(f"Tipos de área: {resultado['tipo_area'].unique()}")
    
    print(f"\n👀 PRIMEROS 10 REGISTROS:")
    print(resultado[['ubigeo', 'departamento', 'provincia', 'distrito', 'tipo_area', 'poblacion']].head(10))
    
    # Guardar resultados
    ruta_destino = r"D:\Mateo\ICSI\Proyecto\Data\Raw\Poblacion\Data\Processing\pob_censo_area_2017.csv"
    resultado.to_csv(ruta_destino, index=False, encoding='latin1')
    print(f"\n💾 Archivo guardado como 'censo_2017_completo.csv'")
    
    # Opcional: guardar versión simplificada
    resultado[['ubigeo', 'departamento', 'provincia', 'distrito', 'tipo_area', 'poblacion', 'anio']].to_csv(
        'censo_2017_simple.csv', index=False, encoding='latin1'
    )
    print("💾 Versión simplificada guardada como 'censo_2017_simple.csv'")
    
else:
    print("❌ No se encontraron datos")
    print("🔍 Mostrando estructura del archivo:")
    for i in range(15):
        fila = df.iloc[i].tolist()
        valores = [str(x) for x in fila if pd.notna(x)]
        if valores:
            print(f"Fila {i}: {valores}")
# Out:
# 🚀 INICIANDO PROCESAMIENTO COMPLETO
# 📌 010101 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Chachapoyas'}
#    ➡️ Urbano censal: 35233
#    ➡️ Rural censal: 634
#    ➡️ Total: 35867
# 📌 010102 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Asunción'}
#    ➡️ Urbano censal: 155
#    ➡️ Rural censal: 127
#    ➡️ Total: 283
# 📌 010103 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Balsas'}
#    ➡️ Urbano censal: 371
#    ➡️ Rural censal: 861
#    ➡️ Total: 1232
# 📌 010104 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Cheto'}
#    ➡️ Urbano censal: 473
#    ➡️ Rural censal: 208
#    ➡️ Total: 681
# 📌 010105 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Chiliquin'}
#    ➡️ Urbano censal: 200
#    ➡️ Rural censal: 427
#    ➡️ Total: 628
# 📌 010106 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Chuquibamba'}
#    ➡️ Urbano censal: 570
#    ➡️ Rural censal: 1408
#    ➡️ Total: 1978
# 📌 010107 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Granada'}
#    ➡️ Urbano censal: 191
#    ➡️ Rural censal: 326
#    ➡️ Total: 517
# 📌 010108 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Huancas'}
#    ➡️ Urbano censal: 1239
#    ➡️ Rural censal: 46
#    ➡️ Total: 1286
# 📌 010109 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'La Jalca'}
#    ➡️ Urbano censal: 2521
#    ➡️ Rural censal: 1731
#    ➡️ Total: 4253
# 📌 010110 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Leimebamba'}
#    ➡️ Urbano censal: 2957
#    ➡️ Rural censal: 913
#    ➡️ Total: 3871
# 📌 010111 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Levanto'}
#    ➡️ Urbano censal: 482
#    ➡️ Rural censal: 355
#    ➡️ Total: 838
# 📌 010112 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Magdalena'}
#    ➡️ Urbano censal: 746
#    ➡️ Rural censal: 166
#    ➡️ Total: 913
# 📌 010113 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Mariscal Castilla'}
#    ➡️ Urbano censal: 1033
#    ➡️ Rural censal: 420
#    ➡️ Total: 1454
# 📌 010114 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Molinopampa'}
#    ➡️ Urbano censal: 694
#    ➡️ Rural censal: 1640
#    ➡️ Total: 2334
# 📌 010115 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Montevideo'}
#    ➡️ Urbano censal: 488
#    ➡️ Rural censal: 39
#    ➡️ Total: 527
# 📌 010116 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Olleros'}
#    ➡️ Urbano censal: 147
#    ➡️ Rural censal: 271
#    ➡️ Total: 418
# 📌 010117 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Quinjalca'}
#    ➡️ Urbano censal: 106
#    ➡️ Rural censal: 721
#    ➡️ Total: 828
# 📌 010118 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'San Francisco de Daguas'}
#    ➡️ Urbano censal: 242
#    ➡️ Rural censal: 78
#    ➡️ Total: 320
# 📌 010119 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'San Isidro de Maino'}
#    ➡️ Urbano censal: 451
#    ➡️ Rural censal: 161
#    ➡️ Total: 613
# 📌 010120 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Soloco'}
#    ➡️ Urbano censal: 240
#    ➡️ Rural censal: 1060
#    ➡️ Total: 1300
# 📌 010121 - {'departamento': 'Amazonas', 'provincia': 'Chachapoyas', 'distrito': 'Sonche'}
#    ➡️ Urbano censal: 110
#    ➡️ Rural censal: 157
#    ➡️ Total: 268
# 📌 010201 - {'departamento': 'Amazonas', 'provincia': 'Bagua', 'distrito': 'Bagua'}
#    ➡️ Urbano censal: 26241
#    ➡️ Rural censal: 2594
#    ➡️ Total: 28836
# 📌 010202 - {'departamento': 'Amazonas', 'provincia': 'Bagua', 'distrito': 'Aramango'}
#    ➡️ Urbano censal: 2935
#    ➡️ Rural censal: 7551
#    ➡️ Total: 10486
# 📌 010203 - {'departamento': 'Amazonas', 'provincia': 'Bagua', 'distrito': 'Copallin'}
#    ➡️ Urbano censal: 2466
#    ➡️ Rural censal: 2505
#    ➡️ Total: 4971
# 📌 010204 - {'departamento': 'Amazonas', 'provincia': 'Bagua', 'distrito': 'El Parco'}
#    ➡️ Urbano censal: 671
#    ➡️ Rural censal: 621
#    ➡️ Total: 1292
# 📌 010205 - {'departamento': 'Amazonas', 'provincia': 'Bagua', 'distrito': 'Imaza'}
#    ➡️ Urbano censal: 5376
#    ➡️ Rural censal: 24475
#    ➡️ Total: 29851
# 📌 010206 - {'departamento': 'Amazonas', 'provincia': 'Bagua', 'distrito': 'La Peca'}
#    ➡️ Urbano censal: 4174
#    ➡️ Rural censal: 2578
#    ➡️ Total: 6753
# 📌 010301 - {'departamento': 'Amazonas', 'provincia': 'Bongara', 'distrito': 'Jumbilla'}
#    ➡️ Urbano censal: 1139
#    ➡️ Rural censal: 245
#    ➡️ Total: 1384
# 📌 010302 - {'departamento': 'Amazonas', 'provincia': 'Bongara', 'distrito': 'Chisquilla'}
#    ➡️ Urbano censal: 126
#    ➡️ Rural censal: 197
#    ➡️ Total: 324
# 📌 010303 - {'departamento': 'Amazonas', 'provincia': 'Bongara', 'distrito': 'Churuja'}
#    ➡️ Urbano censal: 286
#    ➡️ Rural censal: 10
#    ➡️ Total: 297
# 📌 010304 - {'departamento': 'Amazonas', 'provincia': 'Bongara', 'distrito': 'Corosha'}
#    ➡️ Urbano censal: 79
#    ➡️ Rural censal: 725
#    ➡️ Total: 805
# 📌 010305 - {'departamento': 'Amazonas', 'provincia': 'Bongara', 'distrito': 'Cuispes'}
#    ➡️ Urbano censal: 393
#    ➡️ Rural censal: 314
#    ➡️ Total: 707
# 📌 010306 - {'departamento': 'Amazonas', 'provincia': 'Bongara', 'distrito': 'Florida'}
#    ➡️ Urbano censal: 3868
#    ➡️ Rural censal: 2526
#    ➡️ Total: 6395
# 📌 010307 - {'departamento': 'Amazonas', 'provincia': 'Bongara', 'distrito': 'Jazan'}
#    ➡️ Urbano censal: 6788
#    ➡️ Rural censal: 1270
#    ➡️ Total: 8059
# 📌 010308 - {'departamento': 'Amazonas', 'provincia': 'Bongara', 'distrito': 'Recta'}
#    ➡️ Urbano censal: 63
#    ➡️ Rural censal: 157
#    ➡️ Total: 221
# 📌 010309 - {'departamento': 'Amazonas', 'provincia': 'Bongara', 'distrito': 'San Carlos'}
#    ➡️ Urbano censal: 368
#    ➡️ Rural censal: 140
#    ➡️ Total: 508
# 📌 010310 - {'departamento': 'Amazonas', 'provincia': 'Bongara', 'distrito': 'Shipasbamba'}
#    ➡️ Urbano censal: 848
#    ➡️ Rural censal: 765
#    ➡️ Total: 1614
# 📌 010311 - {'departamento': 'Amazonas', 'provincia': 'Bongara', 'distrito': 'Valera'}
#    ➡️ Urbano censal: 300
#    ➡️ Rural censal: 616
#    ➡️ Total: 916
# 📌 010312 - {'departamento': 'Amazonas', 'provincia': 'Bongara', 'distrito': 'Yambrasbamba'}
#    ➡️ Urbano censal: 2283
#    ➡️ Rural censal: 3567
#    ➡️ Total: 5851
# 📌 010401 - {'departamento': 'Amazonas', 'provincia': 'Condorcanqui', 'distrito': 'Nieva'}
#    ➡️ Urbano censal: 4459
#    ➡️ Rural censal: 16864
#    ➡️ Total: 21324
# 📌 010402 - {'departamento': 'Amazonas', 'provincia': 'Condorcanqui', 'distrito': 'El Cenepa'}
#    ➡️ Urbano censal: 1090
#    ➡️ Rural censal: 10567
#    ➡️ Total: 11657
# 📌 010403 - {'departamento': 'Amazonas', 'provincia': 'Condorcanqui', 'distrito': 'Rio Santiago'}
#    ➡️ Urbano censal: 2283
#    ➡️ Rural censal: 14534
#    ➡️ Total: 16818
# 📌 010501 - {'departamento': 'Amazonas', 'provincia': 'Luya', 'distrito': '
- {'departamento': 'Amazonas', 'provincia': 'Rodríguez de Mendoza', 'distrito': 'San Nicolás'}
#    ➡️ Urbano censal: 5130
#    ➡️ Rural censal: 1073
#    ➡️ Total: 6203
# 📌 010602 - {'departamento': 'Amazonas', 'provincia': 'Rodríguez de Mendoza', 'distrito': 'Chirimoto'}
#    ➡️ Urbano censal: 65
#    ➡️ Rural censal: 2593
#    ➡️ Total: 2658
# 📌 010603 - {'departamento': 'Amazonas', 'provincia': 'Rodríguez de Mendoza', 'distrito': 'Cochamal'}
#    ➡️ Urbano censal: 540
#    ➡️ Rural censal: 83
#    ➡️ Total: 623
# 📌 010604 - {'departamento': 'Amazonas', 'provincia': 'Rodríguez de Mendoza', 'distrito': 'Huambo'}
#    ➡️ Urbano censal: 807
#    ➡️ Rural censal: 1993
#    ➡️ Total: 2801
# 📌 010605 - {'departamento': 'Amazonas', 'provincia': 'Rodríguez de Mendoza', 'distrito': 'Limabamba'}
#    ➡️ Urbano censal: 447
#    ➡️ Rural censal: 2056
#    ➡️ Total: 2503
# 📌 010606 - {'departamento': 'Amazonas', 'provincia': 'Rodríguez de Mendoza', 'distrito': 'Longar'}
#    ➡️ Urbano censal: 909
#    ➡️ Rural censal: 800
#    ➡️ Total: 1710
# 📌 010607 - {'departamento': 'Amazonas', 'provincia': 'Rodríguez de Mendoza', 'distrito': 'Mariscal Benavides'}
#    ➡️ Urbano censal: 1050
#    ➡️ Rural censal: 517
#    ➡️ Total: 1567
# 📌 010608 - {'departamento': 'Amazonas', 'provincia': 'Rodríguez de Mendoza', 'distrito': 'Milpuc'}
#    ➡️ Urbano censal: 265
#    ➡️ Rural censal: 203
#    ➡️ Total: 468
# 📌 010609 - {'departamento': 'Amazonas', 'provincia': 'Rodríguez de Mendoza', 'distrito': 'Omia'}
#    ➡️ Urbano censal: 582
#    ➡️ Rural censal: 8875
#    ➡️ Total: 9458
# 📌 010610 - {'departamento': 'Amazonas', 'provincia': 'Rodríguez de Mendoza', 'distrito': 'Santa Rosa'}
#    ➡️ Urbano censal: 159
#    ➡️ Rural censal: 379
#    ➡️ Total: 538
# 📌 010611 - {'departamento': 'Amazonas', 'provincia': 'Rodríguez de Mendoza', 'distrito': 'Totora'}
#    ➡️ Urbano censal: 65
#    ➡️ Rural censal: 229
#    ➡️ Total: 294
# 📌 010612 - {'departamento': 'Amazonas', 'provincia': 'Rodríguez de Mendoza', 'distrito': 'Vista Alegre'}
#    ➡️ Urbano censal: 359
#    ➡️ Rural censal: 2939
#    ➡️ Total: 3299
# 📌 010701 - {'departamento': 'Amazonas', 'provincia': 'Utcubamba', 'distrito': 'Bagua Grande'}
#    ➡️ Urbano censal: 39006
#    ➡️ Rural censal: 16757
#    ➡️ Total: 55764
# 📌 010702 - {'departamento': 'Amazonas', 'provincia': 'Utcubamba', 'distrito': 'Cajaruro'}
#    ➡️ Urbano censal: 8494
#    ➡️ Rural censal: 16609
#    ➡️ Total: 25103
# 📌 010703 - {'departamento': 'Amazonas', 'provincia': 'Utcubamba', 'distrito': 'Cumba'}
#    ➡️ Urbano censal: 3309
#    ➡️ Rural censal: 5558
#    ➡️ Total: 8867
# 📌 010704 - {'departamento': 'Amazonas', 'provincia': 'Utcubamba', 'distrito': 'El Milagro'}
#    ➡️ Urbano censal: 3097
#    ➡️ Rural censal: 3288
#    ➡️ Total: 6385
# 📌 010705 - {'departamento': 'Amazonas', 'provincia': 'Utcubamba', 'distrito': 'Jamalca'}
#    ➡️ Urbano censal: 1404
#    ➡️ Rural censal: 5914
#    ➡️ Total: 7318
# 📌 010706 - {'departamento': 'Amazonas', 'provincia': 'Utcubamba', 'distrito': 'Lonya Grande'}
#    ➡️ Urbano censal: 4016
#    ➡️ Rural censal: 6920
#    ➡️ Total: 10937
# 📌 010707 - {'departamento': 'Amazonas', 'provincia': 'Utcubamba', 'distrito': 'Yamon'}
#    ➡️ Urbano censal: 592
#    ➡️ Rural censal: 2627
#    ➡️ Total: 3220
# 📌 020101 - {'departamento': 'Áncash', 'provincia': 'Huaraz', 'distrito': 'Huaraz'}
#    ➡️ Urbano censal: 59338
#    ➡️ Rural censal: 5666
#    ➡️ Total: 65005
# 📌 020102 - {'departamento': 'Áncash', 'provincia': 'Huaraz', 'distrito': 'Cochabamba'}
#    ➡️ Urbano censal: 475
#    ➡️ Rural censal: 1269
#    ➡️ Total: 1744
# 📌 020103 - {'departamento': 'Áncash', 'provincia': 'Huaraz', 'distrito': 'Colcabamba'}
#    ➡️ Urbano censal: 142
#    ➡️ Rural censal: 181
#    ➡️ Total: 324
# 📌 020104 - {'departamento': 'Áncash', 'provincia': 'Huaraz', 'distrito': 'Huanchay'}
#    ➡️ Urbano censal: 310
#    ➡️ Rural censal: 1426
#    ➡️ Total: 1737
# 📌 020105 - {'departamento': 'Áncash', 'provincia': 'Huaraz', 'distrito': 'Independencia'}
#    ➡️ Urbano censal: 67943
#    ➡️ Rural censal: 12666
#    ➡️ Total: 80610
# 📌 020106 - {'departamento': 'Áncash', 'provincia': 'Huaraz', 'distrito': 'Jangas'}
#    ➡️ Urbano censal: 2628
#    ➡️ Rural censal: 2342
#    ➡️ Total: 4971
# 📌 020107 - {'departamento': 'Áncash', 'provincia': 'Huaraz', 'distrito': 'La Libertad'}
#    ➡️ Urbano censal: 299
#    ➡️ Rural censal: 831
#    ➡️ Total: 1130
# 📌 020108 - {'departamento': 'Áncash', 'provincia': 'Huaraz', 'distrito': 'Olleros'}
#    ➡️ Urbano censal: 1271
#    ➡️ Rural censal: 1224
#    ➡️ Total: 2496
# 📌 020109 - {'departamento': 'Áncash', 'provincia': 'Huaraz', 'distrito': 'Pampas Grande'}
#    ➡️ Urbano censal: 356
#    ➡️ Rural censal: 687
#    ➡️ Total: 1044
# 📌 020110 - {'departamento': 'Áncash', 'provincia': 'Huaraz', 'distrito': 'Pariacoto'}
#    ➡️ Urbano censal: 1354
#    ➡️ Rural censal: 3635
#    ➡️ Total: 4990
# 📌 020111 - {'departamento': 'Áncash', 'provincia': 'Huaraz', 'distrito': 'Pira'}
#    ➡️ Urbano censal: 1200
#    ➡️ Rural censal: 2321
#    ➡️ Total: 3522
# 📌 020112 - {'departamento': 'Áncash', 'provincia': 'Huaraz', 'distrito': 'Tarica'}
#    ➡️ Urbano censal: 1982
#    ➡️ Rural censal: 4976
#    ➡️ Total: 6958
# 📌 020201 - {'departamento': 'Áncash', 'provincia': 'Aija', 'distrito': 'Aija'}
#    ➡️ Urbano censal: 1068
#    ➡️ Rural censal: 1061
#    ➡️ Total: 2130
# 📌 020202 - {'departamento': 'Áncash', 'provincia': 'Aija', 'distrito': 'Coris'}
#    ➡️ Urbano censal: 417
#    ➡️ Rural censal: 1301
#    ➡️ Total: 1719
# 📌 020203 - {'departamento': 'Áncash', 'provincia': 'Aija', 'distrito': 'Huacllan'}
#    ➡️ Urbano censal: 227
#    ➡️ Rural censal: 160
#    ➡️ Total: 388
# 📌 020204 - {'departamento': 'Áncash', 'provincia': 'Aija', 'distrito': 'La Merced'}
#    ➡️ Urbano censal: 280
#    ➡️ Rural censal: 1369
#    ➡️ Total: 1649
# 📌 020205 - {'departamento': 'Áncash', 'provincia': 'Aija', 'distrito': 'Succha'}
#    ➡️ Urbano censal: 312
#    ➡️ Rural censal: 439
#    ➡️ Total: 752
# 📌 020301 - {'departamento': 'Áncash', 'provincia': 'Antonio Raymondi', 'distrito': 'Llamellin'}
#    ➡️ Urbano censal: 1887
#    ➡️ Rural censal: 1569
#    ➡️ Total: 3457
# 📌 020302 - {'departamento': 'Áncash', 'provincia': 'Antonio Raymondi', 'distrito': 'Aczo'}
#    ➡️ Urbano censal: 827
#    ➡️ Rural censal: 1186
#    ➡️ Total: 2013
# 📌 020303 - {'departamento': 'Áncash', 'provincia': 'Antonio Raymondi', 'distrito': 'Chaccho'}
#    ➡️ Urbano censal: 461
#    ➡️ Rural censal: 971
#    ➡️ Total: 1433
# 📌 020304 - {'departamento': 'Áncash', 'provincia': 'Antonio Raymondi', 'distrito': 'Chingas'}
#    ➡️ Urbano censal: 900
#    ➡️ Rural censal: 1048
#    ➡️ Total: 1949
# 📌 020305 - {'departamento': 'Áncash', 'provincia': 'Antonio Raymondi', 'distrito': 'Mirgas'}
#    ➡️ Urbano censal: 1305
#    ➡️ Rural censal: 2984
#    ➡️ Total: 4290
# 📌 020306 - {'departamento': 'Áncash', 'provincia': 'Antonio Raymondi', 'distrito': 'San Juan de Rontoy'}
#    ➡️ Urbano censal: 196
#    ➡️ Rural censal: 1020
#    ➡️ Total: 1216
# 📌 020401 - {'departamento': 'Áncash', 'provincia': 'Asunción', 'distrito': 'Chacas'}
#    ➡️ Urbano censal: 2066
#    ➡️ Rural censal: 2768
#    ➡️ Total: 4834
# 📌 020402 - {'departamento': 'Áncash', 'provincia': 'Asunción', 'distrito': 'Acochaca'}
#    ➡️ Urbano censal: 260
#    ➡️ Rural censal: 2777
#    ➡️ Total: 3038
# 📌 020501 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'Chiquian'}
#    ➡️ Urbano censal: 3790
#    ➡️ Rural censal: 269
#    ➡️ Total: 4060
# 📌 020502 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'Abelardo Pardo Lezameta'}
#    ➡️ Urbano censal: 214
#    ➡️ Rural censal: 45
#    ➡️ Total: 260
# 📌 020503 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'Antonio Raymondi'}
#    ➡️ Urbano censal: 355
#    ➡️ Rural censal: 690
#    ➡️ Total: 1045
# 📌 020504 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'Aquia'}
#    ➡️ Urbano censal: 1155
#    ➡️ Rural censal: 1048
#    ➡️ Total: 2203
# 📌 020505 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'Cajacay'}
#    ➡️ Urbano censal: 709
#    ➡️ Rural censal: 1101
#    ➡️ Total: 1810
# 📌 020506 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'Canis'}
#    ➡️ Urbano censal: 316
#    ➡️ Rural censal: 11
#    ➡️ Total: 328
# 📌 020507 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'Colquioc'}
#    ➡️ Urbano censal: 1740
#    ➡️ Rural censal: 723
#    ➡️ Total: 2463
# 📌 020508 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'Huallanca'}
#    ➡️ Urbano censal: 5658
#    ➡️ Rural censal: 1090
#    ➡️ Total: 6749
# 📌 020509 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'Huasta'}
#    ➡️ Urbano censal: 1161
#    ➡️ Rural censal: 342
#    ➡️ Total: 1504
# 📌 020510 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'Huayllacayan'}
#    ➡️ Urbano censal: 354
#    ➡️ Rural censal: 981
#    ➡️ Total: 1336
# 📌 020511 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'La Primavera'}
#    ➡️ Urbano censal: 361
#    ➡️ Rural censal: 116
#    ➡️ Total: 477
# 📌 020512 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'Mangas'}
#    ➡️ Urbano censal: 388
#    ➡️ Rural censal: 133
#    ➡️ Total: 522
# 📌 020513 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'Pacllon'}
#    ➡️ Urbano censal: 863
#    ➡️ Rural censal: 108
#    ➡️ Total: 971
# 📌 020514 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'San Miguel de Corpanqui'}
#    ➡️ Urbano censal: 432
#    ➡️ Rural censal: 86
#    ➡️ Total: 519
# 📌 020515 - {'departamento': 'Áncash', 'provincia': 'Bolognesi', 'distrito': 'Ticllos'}
#    ➡️ Urbano censal: 597
#    ➡️ Rural censal: 89
#    ➡️ Total: 686
# 📌 020601 - {'departamento': 'Áncash', 'provincia': 'Carhuaz', 'distrito': 'Carhuaz'}
#    ➡️ Urbano censal: 10328
#    ➡️ Rural censal: 5530
#    ➡️ Total: 15859
# 📌 020602 - {'departamento': 'Áncash', 'provincia': 'Carhuaz', 'distrito': 'Acopampa'}
#    ➡️ Urbano censal: 1029
#    ➡️ Rural censal: 1666
#    ➡️ Total: 2696
# 📌 020603 - {'departamento': 'Áncash', 'provincia': 'Carhuaz', 'distrito': 'Amashca'}
#    ➡️ Urbano censal: 754
#    ➡️ Rural censal: 773
#    ➡️ Total: 1528
# 📌 020604 - {'departamento': 'Áncash', 'provincia': 'Carhuaz', 'distrito': 'Anta'}
#    ➡️ Urbano censal: 782
#    ➡️ Rural censal: 1737
#    ➡️ Total: 2520
# 📌 020605 - {'departamento': 'Áncash', 'provincia': 'Carhuaz', 'distrito': 'Ataquero'}
#    ➡️ Urbano censal: 299
#    ➡️ Rural censal: 1274
#    ➡️ Total: 1574
# 📌 020606 - {'departamento': 'Áncash', 'provincia': 'Carhuaz', 'distrito': 'Marcara'}
#    ➡️ Urbano censal: 3923
#    ➡️ Rural censal: 6255
#    ➡️ Total: 10178
# 📌 020607 - {'departamento': 'Áncash', 'provincia': 'Carhuaz', 'distrito': 'Pariahuanca'}
#    ➡️ Urbano censal: 651
#    ➡️ Rural censal: 795
#    ➡️ Total: 1446
# 📌 020608 - {'departamento': 'Áncash', 'provincia': 'Carhuaz', 'distrito': 'San Miguel de Aco'}
#    ➡️ Urbano censal: 405
#    ➡️ Rural censal: 2077
#    ➡️ Total: 2483
# 📌 020609 - {'departamento': 'Áncash', 'provincia': 'Carhuaz', 'distrito': 'Shilla'}
#    ➡️ Urbano censal: 1026
#    ➡️ Rural censal: 1928
#    ➡️ Total: 2955
# 📌 020610 - {'departamento': 'Áncash', 'provincia': 'Carhuaz', 'distrito': 'Tinco'}
#    ➡️ Urbano censal: 1597
#    ➡️ Rural censal: 2010
#    ➡️ Total: 3607
# 📌 020611 - {'departamento': 'Áncash', 'provincia': 'Carhuaz', 'distrito': 'Yungar'}
#    ➡️ Urbano censal: 753
#    ➡️ Rural censal: 2469
#    ➡️ Total: 3222
# 📌 020701 - {'departamento': 'Áncash', 'provincia': 'Carlos Fermín Fitzcarrald', 'distrito': 'San Luis'}
#    ➡️ Urbano censal: 3844
#    ➡️ Rural censal: 7311
#    ➡️ Total: 11155
# 📌 020702 - {'departamento': 'Áncash', 'provincia': 'Carlos Fermín Fitzcarrald', 'distrito': 'San Nicolás'}
#    ➡️ Urbano censal: 1125
#    ➡️ Rural censal: 2198
#    ➡️ Total: 3324
# 📌 020703 - {'departamento': 'Áncash', 'provincia': 'Carlos Fermín Fitzcarrald', 'distrito': 'Yauya'}
#    ➡️ Urbano censal: 908
#    ➡️ Rural censal: 3427
#    ➡️ Total: 4336
# 📌 020801 - {'departamento': 'Áncash', 'provincia': 'Casma', 'distrito': 'Casma'}
#    ➡️ Urbano censal: 34137
#    ➡️ Rural censal: 3052
#    ➡️ Total: 37190
# 📌 020802 - {'departamento': 'Áncash', 'provincia': 'Casma', 'distrito': 'Buena Vista Alta'}
#    ➡️ Urbano censal: 2684
#    ➡️ Rural censal: 2318
#    ➡️ Total: 5003
# 📌 020803 - {'departamento': 'Áncash', 'provincia': 'Casma', 'distrito': 'Comandante Noel'}
#    ➡️ Urbano censal: 1640
#    ➡️ Rural censal: 601
#    ➡️ Total: 2242
# 📌 020804 - {'departamento': 'Áncash', 'provincia': 'Casma', 'distrito': 'Yautan'}
#    ➡️ Urbano censal: 3347
#    ➡️ Rural censal: 5332
#    ➡️ Total: 8680
- {'departamento': 'Áncash', 'provincia': 'Huari', 'distrito': 'San Marcos'}
#    ➡️ Urbano censal: 4739
#    ➡️ Rural censal: 13205
#    ➡️ Total: 17945
# 📌 021015 - {'departamento': 'Áncash', 'provincia': 'Huari', 'distrito': 'San Pedro de Chana'}
#    ➡️ Urbano censal: 1101
#    ➡️ Rural censal: 1561
#    ➡️ Total: 2662
# 📌 021016 - {'departamento': 'Áncash', 'provincia': 'Huari', 'distrito': 'Uco'}
#    ➡️ Urbano censal: 716
#    ➡️ Rural censal: 651
#    ➡️ Total: 1368
# 📌 021101 - {'departamento': 'Áncash', 'provincia': 'Huarmey', 'distrito': 'Huarmey'}
#    ➡️ Urbano censal: 22525
#    ➡️ Rural censal: 3064
#    ➡️ Total: 25590
# 📌 021102 - {'departamento': 'Áncash', 'provincia': 'Huarmey', 'distrito': 'Cochapeti'}
#    ➡️ Urbano censal: 246
#    ➡️ Rural censal: 570
#    ➡️ Total: 816
# 📌 021103 - {'departamento': 'Áncash', 'provincia': 'Huarmey', 'distrito': 'Culebras'}
#    ➡️ Urbano censal: 1802
#    ➡️ Rural censal: 1502
#    ➡️ Total: 3304
# 📌 021104 - {'departamento': 'Áncash', 'provincia': 'Huarmey', 'distrito': 'Huayan'}
#    ➡️ Urbano censal: 398
#    ➡️ Rural censal: 574
#    ➡️ Total: 973
# 📌 021105 - {'departamento': 'Áncash', 'provincia': 'Huarmey', 'distrito': 'Malvas'}
#    ➡️ Urbano censal: 360
#    ➡️ Rural censal: 443
#    ➡️ Total: 804
# 📌 021201 - {'departamento': 'Áncash', 'provincia': 'Huaylas', 'distrito': 'Caraz'}
#    ➡️ Urbano censal: 15943
#    ➡️ Rural censal: 9968
#    ➡️ Total: 25912
# 📌 021202 - {'departamento': 'Áncash', 'provincia': 'Huaylas', 'distrito': 'Huallanca'}
#    ➡️ Urbano censal: 550
#    ➡️ Rural censal: 511
#    ➡️ Total: 1062
# 📌 021203 - {'departamento': 'Áncash', 'provincia': 'Huaylas', 'distrito': 'Huata'}
#    ➡️ Urbano censal: 225
#    ➡️ Rural censal: 1193
#    ➡️ Total: 1419
# 📌 021204 - {'departamento': 'Áncash', 'provincia': 'Huaylas', 'distrito': 'Huaylas'}
#    ➡️ Urbano censal: 410
#    ➡️ Rural censal: 1305
#    ➡️ Total: 1716
# 📌 021205 - {'departamento': 'Áncash', 'provincia': 'Huaylas', 'distrito': 'Mato'}
#    ➡️ Urbano censal: 1025
#    ➡️ Rural censal: 945
#    ➡️ Total: 1970
# 📌 021206 - {'departamento': 'Áncash', 'provincia': 'Huaylas', 'distrito': 'Pamparomas'}
#    ➡️ Urbano censal: 485
#    ➡️ Rural censal: 7990
#    ➡️ Total: 8476
# 📌 021207 - {'departamento': 'Áncash', 'provincia': 'Huaylas', 'distrito': 'Pueblo Libre'}
#    ➡️ Urbano censal: 528
#    ➡️ Rural censal: 6358
#    ➡️ Total: 6887
# 📌 021208 - {'departamento': 'Áncash', 'provincia': 'Huaylas', 'distrito': 'Santa Cruz'}
#    ➡️ Urbano censal: 732
#    ➡️ Rural censal: 3850
#    ➡️ Total: 4582
# 📌 021209 - {'departamento': 'Áncash', 'provincia': 'Huaylas', 'distrito': 'Santo Toribio'}
#    ➡️ Urbano censal: 283
#    ➡️ Rural censal: 852
#    ➡️ Total: 1135
# 📌 021210 - {'departamento': 'Áncash', 'provincia': 'Huaylas', 'distrito': 'Yuracmarca'}
#    ➡️ Urbano censal: 487
#    ➡️ Rural censal: 1599
#    ➡️ Total: 2086
# 📌 021301 - {'departamento': 'Áncash', 'provincia': 'Mariscal Luzuriaga', 'distrito': 'Piscobamba'}
#    ➡️ Urbano censal: 1508
#    ➡️ Rural censal: 1670
#    ➡️ Total: 3179
# 📌 021302 - {'departamento': 'Áncash', 'provincia': 'Mariscal Luzuriaga', 'distrito': 'Casca'}
#    ➡️ Rural censal: 11359
#    ➡️ Total: 21577
# 📌 022002 - {'departamento': 'Áncash', 'provincia': 'Yungay', 'distrito': 'Cascapara'}
#    ➡️ Urbano censal: 167
#    ➡️ Rural censal: 1580
#    ➡️ Total: 1748
# 📌 022003 - {'departamento': 'Áncash', 'provincia': 'Yungay', 'distrito': 'Mancos'}
#    ➡️ Urbano censal: 2461
#    ➡️ Rural censal: 4401
#    ➡️ Total: 6862
# 📌 022004 - {'departamento': 'Áncash', 'provincia': 'Yungay', 'distrito': 'Matacoto'}
#    ➡️ Urbano censal: 352
#    ➡️ Rural censal: 1143
#    ➡️ Total: 1495
# 📌 022005 - {'departamento': 'Áncash', 'provincia': 'Yungay', 'distrito': 'Quillo'}
#    ➡️ Urbano censal: 1392
#    ➡️ Rural censal: 11368
#    ➡️ Total: 12761
# 📌 022006 - {'departamento': 'Áncash', 'provincia': 'Yungay', 'distrito': 'Ranrahirca'}
#    ➡️ Urbano censal: 1076
#    ➡️ Rural censal: 1822
#    ➡️ Total: 2898
# 📌 022007 - {'departamento': 'Áncash', 'provincia': 'Yungay', 'distrito': 'Shupluy'}
#    ➡️ Urbano censal: 210
#    ➡️ Rural censal: 1744
#    ➡️ Total: 1955
# 📌 022008 - {'departamento': 'Áncash', 'provincia': 'Yungay', 'distrito': 'Yanama'}
#    ➡️ Urbano censal: 465
#    ➡️ Rural censal: 5135
#    ➡️ Total: 5601
# 📌 030101 - {'departamento': 'Apurímac', 'provincia': 'Abancay', 'distrito': 'Abancay'}
#    ➡️ Urbano censal: 64873
#    ➡️ Rural censal: 6386
#    ➡️ Total: 71259
# 📌 030102 - {'departamento': 'Apurímac', 'provincia': 'Abancay', 'distrito': 'Chacoche'}
#    ➡️ Urbano censal: 1073
#    ➡️ Rural censal: 322
#    ➡️ Total: 1396
# 📌 030103 - {'departamento': 'Apurímac', 'provincia': 'Abancay', 'distrito': 'Circa'}
#    ➡️ Urbano censal: 379
#    ➡️ Rural censal: 1572
#    ➡️ Total: 1951
# 📌 030104 - {'departamento': 'Apurímac', 'provincia': 'Abancay', 'distrito': 'Curahuasi'}
#    ➡️ Urbano censal: 7485
#    ➡️ Rural censal: 9579
#    ➡️ Total: 17064
# 📌 030105 - {'departamento': 'Apurímac', 'provincia': 'Abancay', 'distrito': 'Huanipaca'}
#    ➡️ Urbano censal: 650
#    ➡️ Rural censal: 2418
#    ➡️ Total: 3068
# 📌 030106 - {'departamento': 'Apurímac', 'provincia': 'Abancay', 'distrito': 'Lambrama'}
#    ➡️ Urbano censal: 1189
#    ➡️ Rural censal: 1979
#    ➡️ Total: 3169
# 📌 030107 - {'departamento': 'Apurímac', 'provincia': 'Abancay', 'distrito': 'Pichirhua'}
#    ➡️ Urbano censal: 521
#    ➡️ Rural censal: 2406
#    ➡️ Total: 2927
# 📌 030108 - {'departamento': 'Apurímac', 'provincia': 'Abancay', 'distrito': 'San Pedro de Cachora'}
#    ➡️ Urbano censal: 776
#    ➡️ Rural censal: 1902
#    ➡️ Total: 2678
# 📌 030109 - {'departamento': 'Apurímac', 'provincia': 'Abancay', 'distrito': 'Tamburco'}
#    ➡️ Urbano censal: 9359
#    ➡️ Rural censal: 1844
#    ➡️ Total: 11204
# 📌 030201 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Andahuaylas'}
#    ➡️ Urbano censal: 35499
#    ➡️ Rural censal: 8060
#    ➡️ Total: 43559
# 📌 030202 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Andarapa'}
#    ➡️ Urbano censal: 1419
#    ➡️ Rural censal: 4337
#    ➡️ Total: 5756
# 📌 030203 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Chiara'}
#    ➡️ Urbano censal: 764
#    ➡️ Rural censal: 473
#    ➡️ Total: 1237
# 📌 030204 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Huancarama'}
#    ➡️ Urbano censal: 3054
#    ➡️ Rural censal: 2399
#    ➡️ Total: 5453
# 📌 030205 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Huancaray'}
#    ➡️ Urbano censal: 452
#    ➡️ Rural censal: 3512
#    ➡️ Total: 3964
# 📌 030206 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Huayana'}
#    ➡️ Urbano censal: 502
#    ➡️ Rural censal: 290
#    ➡️ Total: 793
# 📌 030207 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Kishuara'}
#    ➡️ Urbano censal: 1551
#    ➡️ Rural censal: 4901
#    ➡️ Total: 6453
# 📌 030208 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Pacobamba'}
#    ➡️ Urbano censal: 487
#    ➡️ Rural censal: 3130
#    ➡️ Total: 3618
# 📌 030209 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Pacucha'}
#    ➡️ Urbano censal: 1114
#    ➡️ Rural censal: 7566
#    ➡️ Total: 8681
# 📌 030210 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Pampachiri'}
#    ➡️ Urbano censal: 671
#    ➡️ Rural censal: 1646
#    ➡️ Total: 2317
# 📌 030211 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Pomacocha'}
#    ➡️ Urbano censal: 658
#    ➡️ Rural censal: 252
#    ➡️ Total: 910
# 📌 030212 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'San Antonio de Cachi'}
#    ➡️ Urbano censal: 1498
#    ➡️ Rural censal: 1548
#    ➡️ Total: 3047
# 📌 030213 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'San Jerónimo'}
#    ➡️ Urbano censal: 12816
#    ➡️ Rural censal: 9098
#    ➡️ Total: 21914
# 📌 030214 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'San Miguel de Chaccrampa'}
#    ➡️ Urbano censal: 662
#    ➡️ Rural censal: 1031
#    ➡️ Total: 1693
# 📌 030215 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Santa María de Chicmo'}
#    ➡️ Urbano censal: 4540
#    ➡️ Rural censal: 4229
#    ➡️ Total: 8769
# 📌 030216 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Talavera'}
#    ➡️ Urbano censal: 11764
#    ➡️ Rural censal: 7486
#    ➡️ Total: 19251
# 📌 030217 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Tumay Huaraca'}
#    ➡️ Urbano censal: 538
#    ➡️ Rural censal: 1426
#    ➡️ Total: 1964
# 📌 030218 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Turpo'}
#    ➡️ Urbano censal: 1184
#    ➡️ Rural censal: 2630
#    ➡️ Total: 3815
# 📌 030219 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'Kaquiabamba'}
#    ➡️ Urbano censal: 1195
#    ➡️ Rural censal: 680
#    ➡️ Total: 1875
# 📌 030220 - {'departamento': 'Apurímac', 'provincia': 'Andahuaylas', 'distrito': 'José María Arguedas'}
#    ➡️ Urbano censal: 2936
#    ➡️ Rural censal: 1249
#    ➡️ Total: 4185
# 📌 030301 - {'departamento': 'Apurímac', 'provincia': 'Antabamba', 'distrito': 'Antabamba'}
#    ➡️ Urbano censal: 2160
#    ➡️ Rural censal: 764
#    ➡️ Total: 2924
# 📌 030302 - {'departamento': 'Apurímac', 'provincia': 'Antabamba', 'distrito': 'El Oro'}
#    ➡️ Urbano censal: 460
#    ➡️ Rural censal: 116
#    ➡️ Total: 576
# 📌 030303 - {'departamento': 'Apurímac', 'provincia': 'Antabamba', 'distrito': 'Huaquirca'}
#    ➡️ Urbano censal: 1282
#    ➡️ Rural censal: 626
#    ➡️ Total: 1908
# 📌 030304 - {'departamento': 'Apurímac', 'provincia': 'Antabamba', 'distrito': 'Juan Espinoza Medrano'}
- {'departamento': 'Apurímac', 'provincia': 'Aymaraes', 'distrito': 'Toraya'}
#    ➡️ Urbano censal: 450
#    ➡️ Rural censal: 896
#    ➡️ Total: 1346
# 📌 030417 - {'departamento': 'Apurímac', 'provincia': 'Aymaraes', 'distrito': 'Yanaca'}
#    ➡️ Urbano censal: 598
#    ➡️ Rural censal: 428
#    ➡️ Total: 1027
# 📌 030501 - {'departamento': 'Apurímac', 'provincia': 'Cotabambas', 'distrito': 'Tambobamba'}
#    ➡️ Urbano censal: 4591
#    ➡️ Rural censal: 6165
#    ➡️ Total: 10756
# 📌 030502 - {'departamento': 'Apurímac', 'provincia': 'Cotabambas', 'distrito': 'Cotabambas'}
#    ➡️ Urbano censal: 1696
#    ➡️ Rural censal: 2410
#    ➡️ Total: 4106
# 📌 030503 - {'departamento': 'Apurímac', 'provincia': 'Cotabambas', 'distrito': 'Coyllurqui'}
#    ➡️ Urbano censal: 1022
# ...
#    ➡️ Total: 2137
# 📌 220704 - {'departamento': 'San Martín', 'provincia': 'Picota', 'distrito': 'Pilluana'}
#    ➡️ Urbano censal: 847
#    ➡️ Rural censal: 38
#    ➡️ Total: 885
# 📌 220705 - {'departamento': 'San Martín', 'provincia': 'Picota', 'distrito': 'Pucacaca'}
#    ➡️ Urbano censal: 2804
#    ➡️ Rural censal: 191
#    ➡️ Total: 2996
# 📌 220706 - {'departamento': 'San Martín', 'provincia': 'Picota', 'distrito': 'San Cristóbal'}
#    ➡️ Urbano censal: 1222
#    ➡️ Total: 1222
# 📌 220707 - {'departamento': 'San Martín', 'provincia': 'Picota', 'distrito': 'San Hilarión'}
#    ➡️ Urbano censal: 2846
#    ➡️ Rural censal: 1101
#    ➡️ Total: 3947
# 📌 220708 - {'departamento': 'San Martín', 'provincia': 'Picota', 'distrito': 'Shamboyacu'}
#    ➡️ Urbano censal: 2713
#    ➡️ Rural censal: 6957
#    ➡️ Total: 9670
# 📌 220709 - {'departamento': 'San Martín', 'provincia': 'Picota', 'distrito': 'Tingo de Ponasa'}
#    ➡️ Urbano censal: 2539
#    ➡️ Rural censal: 1377
#    ➡️ Total: 3917
# 📌 220710 - {'departamento': 'San Martín', 'provincia': 'Picota', 'distrito': 'Tres Unidos'}
#    ➡️ Urbano censal: 1914
#    ➡️ Rural censal: 2225
#    ➡️ Total: 4140
# 📌 220801 - {'departamento': 'San Martín', 'provincia': 'Rioja', 'distrito': 'Rioja'}
#    ➡️ Urbano censal: 23881
#    ➡️ Rural censal: 1983
#    ➡️ Total: 25865
# 📌 220802 - {'departamento': 'San Martín', 'provincia': 'Rioja', 'distrito': 'Awajun'}
#    ➡️ Urbano censal: 2995
#    ➡️ Rural censal: 4896
#    ➡️ Total: 7891
# 📌 220803 - {'departamento': 'San Martín', 'provincia': 'Rioja', 'distrito': 'Elías Soplin Vargas'}
#    ➡️ Urbano censal: 15178
#    ➡️ Rural censal: 2835
#    ➡️ Total: 18013
# 📌 220804 - {'departamento': 'San Martín', 'provincia': 'Rioja', 'distrito': 'Nueva Cajamarca'}
#    ➡️ Urbano censal: 37507
#    ➡️ Rural censal: 7089
#    ➡️ Total: 44597
# 📌 220805 - {'departamento': 'San Martín', 'provincia': 'Rioja', 'distrito': 'Pardo Miguel'}
#    ➡️ Urbano censal: 9912
#    ➡️ Rural censal: 7370
#    ➡️ Total: 17282
# 📌 220806 - {'departamento': 'San Martín', 'provincia': 'Rioja', 'distrito': 'Posic'}
#    ➡️ Urbano censal: 1688
#    ➡️ Rural censal: 251
#    ➡️ Total: 1940
# 📌 220807 - {'departamento': 'San Martín', 'provincia': 'Rioja', 'distrito': 'San Fernando'}
#    ➡️ Urbano censal: 2412
#    ➡️ Rural censal: 1311
#    ➡️ Total: 3723
# 📌 220808 - {'departamento': 'San Martín', 'provincia': 'Rioja', 'distrito': 'Yorongos'}
#    ➡️ Urbano censal: 2162
#    ➡️ Rural censal: 531
#    ➡️ Total: 2694
# 📌 220809 - {'departamento': 'San Martín', 'provincia': 'Rioja', 'distrito': 'Yuracyacu'}
#    ➡️ Urbano censal: 3477
#    ➡️ Rural censal: 426
#    ➡️ Total: 3904
# 📌 220901 - {'departamento': 'San Martín', 'provincia': 'San Martín', 'distrito': '
- {'departamento': 'Tacna', 'provincia': 'Tacna', 'distrito': 'Tacna'}
#    ➡️ Urbano censal: 99906
#    ➡️ Rural censal: 705
#    ➡️ Total: 100612
# 📌 230102 - {'departamento': 'Tacna', 'provincia': 'Tacna', 'distrito': 'Alto de la Alianza'}
#    ➡️ Urbano censal: 35076
#    ➡️ Rural censal: 110
#    ➡️ Total: 35186
# 📌 230103 - {'departamento': 'Tacna', 'provincia': 'Tacna', 'distrito': 'Calana'}
#    ➡️ Urbano censal: 1176
#    ➡️ Rural censal: 2050
#    ➡️ Total: 3226
# 📌 230104 - {'departamento': 'Tacna', 'provincia': 'Tacna', 'distrito': 'Ciudad Nueva'}
#    ➡️ Urbano censal: 32917
#    ➡️ Rural censal: 107
#    ➡️ Total: 33024
# 📌 230105 - {'departamento': 'Tacna', 'provincia': 'Tacna', 'distrito': 'Inclan'}
#    ➡️ Urbano censal: 1276
#    ➡️ Rural censal: 1636
#    ➡️ Total: 2912
# 📌 230106 - {'departamento': 'Tacna', 'provincia': 'Tacna', 'distrito': 'Pachia'}
#    ➡️ Urbano censal: 1445
#    ➡️ Rural censal: 748
#    ➡️ Total: 2194
# 📌 230107 - {'departamento': 'Tacna', 'provincia': 'Tacna', 'distrito': 'Palca'}
#    ➡️ Urbano censal: 702
#    ➡️ Rural censal: 1303
#    ➡️ Total: 2005
# 📌 230108 - {'departamento': 'Tacna', 'provincia': 'Tacna', 'distrito': 'Pocollay'}
#    ➡️ Urbano censal: 18133
#    ➡️ Rural censal: 700
#    ➡️ Total: 18834
# 📌 230109 - {'departamento': 'Tacna', 'provincia': 'Tacna', 'distrito': 'Sama'}
#    ➡️ Urbano censal: 2734
#    ➡️ Rural censal: 617
#    ➡️ Total: 3351
# 📌 230110 - {'departamento': 'Tacna', 'provincia': 'Tacna', 'distrito': 'Coronel Gregorio Albarracin Lanchipa'}
#    ➡️ Urbano censal: 116279
#    ➡️ Rural censal: 356
#    ➡️ Total: 116635
# 📌 230111 - {'departamento': 'Tacna', 'provincia': 'Tacna', 'distrito': 'La Yarada los Palos'}
#    ➡️ Urbano censal: 237
#    ➡️ Rural censal: 6195
#    ➡️ Total: 6433
# 📌 230201 - {'departamento': 'Tacna', 'provincia': 'Candarave', 'distrito': 'Candarave'}
#    ➡️ Urbano censal: 1694
#    ➡️ Rural censal: 807
#    ➡️ Total: 2501
# 📌 230202 - {'departamento': 'Tacna', 'provincia': 'Candarave', 'distrito': 'Cairani'}
#    ➡️ Urbano censal: 1015
#    ➡️ Rural censal: 20
#    ➡️ Total: 1035
# 📌 230203 - {'departamento': 'Tacna', 'provincia': 'Candarave', 'distrito': 'Camilaca'}
#    ➡️ Urbano censal: 1116
#    ➡️ Rural censal: 104
#    ➡️ Total: 1220
# 📌 230204 - {'departamento': 'Tacna', 'provincia': 'Candarave', 'distrito': 'Curibaya'}
#    ➡️ Urbano censal: 305
#    ➡️ Rural censal: 96
#    ➡️ Total: 401
# 📌 230205 - {'departamento': 'Tacna', 'provincia': 'Candarave', 'distrito': 'Huanuara'}
#    ➡️ Urbano censal: 496
#    ➡️ Rural censal: 39
#    ➡️ Total: 535
# 📌 230206 - {'departamento': 'Tacna', 'provincia': 'Candarave', 'distrito': 'Quilahuani'}
#    ➡️ Urbano censal: 636
#    ➡️ Rural censal: 116
#    ➡️ Total: 753
# 📌 230301 - {'departamento': 'Tacna', 'provincia': 'Jorge Basadre', 'distrito': 'Locumba'}
#    ➡️ Urbano censal: 1362
#    ➡️ Rural censal: 1168
#    ➡️ Total: 2531
# 📌 230302 - {'departamento': 'Tacna', 'provincia': 'Jorge Basadre', 'distrito': 'Ilabaya'}
#    ➡️ Urbano censal: 5405
#    ➡️ Rural censal: 663
#    ➡️ Total: 6069
# 📌 230303 - {'departamento': 'Tacna', 'provincia': 'Jorge Basadre', 'distrito': 'Ite'}
#    ➡️ Urbano censal: 2109
#    ➡️ Rural censal: 1098
#    ➡️ Total: 3208
# 📌 230401 - {'departamento': 'Tacna', 'provincia': 'Tarata', 'distrito': 'Tarata'}
#    ➡️ Urbano censal: 2860
#    ➡️ Rural censal: 875
#    ➡️ Total: 3735
# 📌 230402 - {'departamento': 'Tacna', 'provincia': 'Tarata', 'distrito': 'Héroes Albarracín'}
#    ➡️ Urbano censal: 144
#    ➡️ Rural censal: 190
#    ➡️ Total: 334
# 📌 230403 - {'departamento': 'Tacna', 'provincia': 'Tarata', 'distrito': 'Estique'}
#    ➡️ Urbano censal: 234
#    ➡️ Rural censal: 26
#    ➡️ Total: 261
# 📌 230404 - {'departamento': 'Tacna', 'provincia': 'Tarata', 'distrito': 'Estique-Pampa'}
#    ➡️ Urbano censal: 171
#    ➡️ Rural censal: 3
#    ➡️ Total: 175
# 📌 230405 - {'departamento': 'Tacna', 'provincia': 'Tarata', 'distrito': 'Sitajara'}
#    ➡️ Urbano censal: 367
#    ➡️ Rural censal: 3
#    ➡️ Total: 370
# 📌 230406 - {'departamento': 'Tacna', 'provincia': 'Tarata', 'distrito': 'Susapaya'}
#    ➡️ Urbano censal: 470
#    ➡️ Rural censal: 74
#    ➡️ Total: 544
# 📌 230407 - {'departamento': 'Tacna', 'provincia': 'Tarata', 'distrito': 'Tarucachi'}
#    ➡️ Urbano censal: 313
#    ➡️ Rural censal: 20
#    ➡️ Total: 334
# 📌 230408 - {'departamento': 'Tacna', 'provincia': 'Tarata', 'distrito': 'Ticaco'}
#    ➡️ Urbano censal: 577
#    ➡️ Rural censal: 44
#    ➡️ Total: 621
# 📌 240101 - {'departamento': 'Tumbes', 'provincia': 'Tumbes', 'distrito': 'Tumbes'}
#    ➡️ Urbano censal: 105660
#    ➡️ Rural censal: 1405
#    ➡️ Total: 107065
# 📌 240102 - {'departamento': 'Tumbes', 'provincia': 'Tumbes', 'distrito': 'Corrales'}
#    ➡️ Urbano censal: 23155
#    ➡️ Rural censal: 947
#    ➡️ Total: 24102
# 📌 240103 - {'departamento': 'Tumbes', 'provincia': 'Tumbes', 'distrito': 'La Cruz'}
#    ➡️ Urbano censal: 9318
#    ➡️ Rural censal: 547
#    ➡️ Total: 9865
# 📌 240104 - {'departamento': 'Tumbes', 'provincia': 'Tumbes', 'distrito': 'Pampas de Hospital'}
#    ➡️ Urbano censal: 3814
#    ➡️ Rural censal: 3324
#    ➡️ Total: 7138
# 📌 240105 - {'departamento': 'Tumbes', 'provincia': 'Tumbes', 'distrito': 'San Jacinto'}
#    ➡️ Urbano censal: 7093
#    ➡️ Rural censal: 1520
#    ➡️ Total: 8613
# 📌 240106 - {'departamento': 'Tumbes', 'provincia': 'Tumbes', 'distrito': 'San Juan de la Virgen'}
#    ➡️ Urbano censal: 4492
#    ➡️ Rural censal: 88
#    ➡️ Total: 4581
# 📌 240201 - {'departamento': 'Tumbes', 'provincia': 'Contralmirante Villar', 'distrito': 'Zorritos'}
#    ➡️ Urbano censal: 12201
#    ➡️ Rural censal: 506
#    ➡️ Total: 12708
# 📌 240202 - {'departamento': 'Tumbes', 'provincia': 'Contralmirante Villar', 'distrito': 'Casitas'}
#    ➡️ Urbano censal: 396
#    ➡️ Rural censal: 2135
#    ➡️ Total: 2532
# 📌 240203 - {'departamento': 'Tumbes', 'provincia': 'Contralmirante Villar', 'distrito': 'Canoas de Punta Sal'}
#    ➡️ Urbano censal: 5410
#    ➡️ Rural censal: 1255
#    ➡️ Total: 6666
# 📌 240301 - {'departamento': 'Tumbes', 'provincia': 'Zarumilla', 'distrito': 'Zarumilla'}
#    ➡️ Urbano censal: 22962
#    ➡️ Rural censal: 374
#    ➡️ Total: 23336
# 📌 240302 - {'departamento': 'Tumbes', 'provincia': 'Zarumilla', 'distrito': 'Aguas Verdes'}
#    ➡️ Urbano censal: 17869
#    ➡️ Rural censal: 299
#    ➡️ Total: 18169
# 📌 240303 - {'departamento': 'Tumbes', 'provincia': 'Zarumilla', 'distrito': 'Matapalo'}
#    ➡️ Urbano censal: 2859
#    ➡️ Rural censal: 575
#    ➡️ Total: 3435
# 📌 240304 - {'departamento': 'Tumbes', 'provincia': 'Zarumilla', 'distrito': 'Papayal'}
#    ➡️ Urbano censal: 4403
#    ➡️ Rural censal: 2078
#    ➡️ Total: 6482
# 📌 250101 - {'departamento': 'Ucayali', 'provincia': 'Coronel Portillo', 'distrito': 'Calleria'}
#    ➡️ Urbano censal: 155992
#    ➡️ Rural censal: 6830
#    ➡️ Total: 162823
# 📌 250102 - {'departamento': 'Ucayali', 'provincia': 'Coronel Portillo', 'distrito': 'Campoverde'}
#    ➡️ Urbano censal: 7429
#    ➡️ Rural censal: 10570
#    ➡️ Total: 17999
# 📌 250103 - {'departamento': 'Ucayali', 'provincia': 'Coronel Portillo', 'distrito': 'Iparia'}
#    ➡️ Urbano censal: 1450
#    ➡️ Rural censal: 10458
#    ➡️ Total: 11909
# 📌 250104 - {'departamento': 'Ucayali', 'provincia': 'Coronel Portillo', 'distrito': 'Masisea'}
#    ➡️ Urbano censal: 3460
#    ➡️ Rural censal: 8334
#    ➡️ Total: 11795
# 📌 250105 - {'departamento': 'Ucayali', 'provincia': 'Coronel Portillo', 'distrito': 'Yarinacocha'}
#    ➡️ Urbano censal: 104720
#    ➡️ Rural censal: 5417
#    ➡️ Total: 110138
# 📌 250106 - {'departamento': 'Ucayali', 'provincia': 'Coronel Portillo', 'distrito': 'Nueva Requena'}
#    ➡️ Urbano censal: 2610
#    ➡️ Rural censal: 2949
#    ➡️ Total: 5560
# 📌 250107 - {'departamento': 'Ucayali', 'provincia': 'Coronel Portillo', 'distrito': 'Manantay'}
#    ➡️ Urbano censal: 95643
#    ➡️ Rural censal: 2185
#    ➡️ Total: 97828
# 📌 250201 - {'departamento': 'Ucayali', 'provincia': 'Atalaya', 'distrito': 'Raymondi'}
#    ➡️ Urbano censal: 17810
#    ➡️ Rural censal: 19971
#    ➡️ Total: 37781
# 📌 250202 - {'departamento': 'Ucayali', 'provincia': 'Atalaya', 'distrito': 'Sepahua'}
#    ➡️ Urbano censal: 3666
#    ➡️ Rural censal: 4174
#    ➡️ Total: 7841
# 📌 250203 - {'departamento': 'Ucayali', 'provincia': 'Atalaya', 'distrito': 'Tahuania'}
#    ➡️ Urbano censal: 2591
#    ➡️ Rural censal: 7154
#    ➡️ Total: 9745
# 📌 250204 - {'departamento': 'Ucayali', 'provincia': 'Atalaya', 'distrito': 'Yurua'}
#    ➡️ Urbano censal: 607
#    ➡️ Rural censal: 1614
#    ➡️ Total: 2222
# 📌 250301 - {'departamento': 'Ucayali', 'provincia': 'Padre Abad', 'distrito': 'Padre Abad'}
#    ➡️ Urbano censal: 27062
#    ➡️ Rural censal: 7756
#    ➡️ Total: 34818
# 📌 250302 - {'departamento': 'Ucayali', 'provincia': 'Padre Abad', 'distrito': 'Irazola'}
#    ➡️ Urbano censal: 6922
#    ➡️ Rural censal: 4018
#    ➡️ Total: 10940
# 📌 250303 - {'departamento': 'Ucayali', 'provincia': 'Padre Abad', 'distrito': 'Curimana'}
#    ➡️ Urbano censal: 4326
#    ➡️ Rural censal: 4831
#    ➡️ Total: 9158
# 📌 250304 - {'departamento': 'Ucayali', 'provincia': 'Padre Abad', 'distrito': 'Neshuya'}
#    ➡️ Urbano censal: 4518
#    ➡️ Rural censal: 4484
#    ➡️ Total: 9002
# 📌 250305 - {'departamento': 'Ucayali', 'provincia': 'Padre Abad', 'distrito': 'Alexander Von Humboldt'}
#    ➡️ Urbano censal: 4564
#    ➡️ Rural censal: 1520
#    ➡️ Total: 6084
# 📌 250401 - {'departamento': 'Ucayali', 'provincia': 'Purús', 'distrito': 'Purús'}
#    ➡️ Urbano censal: 1411
#    ➡️ Rural censal: 1934
#    ➡️ Total: 3345
#
# ✅ PROCESAMIENTO COMPLETO EXITOSO!
# 📊 Total de registros: 5550
#
# 📈 ESTADÍSTICAS:
# Departamentos únicos: 25
# Provincias únicas: 202
# Distritos únicos: 1719
# Tipos de área: ['Urbano censal' 'Rural censal' 'Total']
#
# 👀 PRIMEROS 10 REGISTROS:
#    ubigeo departamento    provincia     distrito      tipo_area  poblacion
# 0  010101     Amazonas  Chachapoyas  Chachapoyas  Urbano censal      35233
# 1  010101     Amazonas  Chachapoyas  Chachapoyas   Rural censal        634
# 2  010101     Amazonas  Chachapoyas  Chachapoyas          Total      35867
# 3  010102     Amazonas  Chachapoyas     Asunción  Urbano censal        155
# 4  010102     Amazonas  Chachapoyas     Asunción   Rural censal        127
# 5  010102     Amazonas  Chachapoyas     Asunción          Total        283
# 6  010103     Amazonas  Chachapoyas       Balsas  Urbano censal        371
# 7  010103     Amazonas  Chachapoyas       Balsas   Rural censal        861
# 8  010103     Amazonas  Chachapoyas       Balsas          Total       1232
# 9  010104     Amazonas  Chachapoyas        Cheto  Urbano censal        473
#
# 💾 Archivo guardado como 'censo_2017_completo.csv'
# 💾 Versión simplificada guardada como 'censo_2017_simple.csv'
